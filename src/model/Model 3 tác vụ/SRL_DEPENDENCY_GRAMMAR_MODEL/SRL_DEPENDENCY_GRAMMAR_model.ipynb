# %% [markdown]
# # EXAMPLE - 5
#
# **Tasks :- NER tagging, POS tagging**
#
# **Tasks Description**
#
# ``NER`` :-This is a Named Entity Recognition task where individual words of the sentence are tagged with an entity label it belongs to. The words which don't belong to any entity label are simply labeled as "O".
#
# ``POS`` :- This is a Part of Speech tagging task. A part of speech is a category of words that have similar grammatical properties. Each word of the sentence is tagged with the part of speech label it belongs to. The words which don't belong to any part of speech label are simply labeled as "O".
#
# **Conversational Utility** :-  In conversational AI context, determining the syntactic parts of the sentence can help in extracting noun-phrases or important keyphrases from the sentence.
#
# **Data** :- In this example, we are using the <a href="https://www.clips.uantwerpen.be/conll2003/ner/">coNLL 2003</a> data which is BIO tagged format with the POS and NER tags separated by space.
#
# The data is already present in ``coNLL_data`` directory.

# %% [markdown]
# # Step - 1: Transforming data
#
# Raw data is in BIO tagged format with the POS and NER tags separated by space.
#
# We already provide a sample transformation function ``coNLL_ner_pos_to_tsv`` to convert this data to required tsv format.
#
# Running data transformations will save the required train, dev and test tsv data files under ``data`` directory in root of library. For more details on the data transformation process, refer to <a href="https://multi-task-nlp.readthedocs.io/en/latest/data_transformations.html">data transformations</a> in documentation.
#
# The transformation file should have the following details which is already created ``transform_file_conll.yml``.
#
# ```
# transform1:
#   transform_func: coNLL_ner_pos_to_tsv
#   read_file_names:
#     - coNLL_train.txt
#     - coNLL_testa.txt
#     - coNLL_testb.txt
#   read_dir: coNLL_data
#   save_dir: ../../data
#  ```
#  Following command can be used to run the data transformation for the tasks.

# %%
# !python ./../data_transformations.py \
    --transform_file 'transform_file_conll.yml'
# Out:
# /home/tiendat/anaconda3/envs/thesis/lib/python3.9/site-packages/transformers/generation_utils.py:24: FutureWarning: Importing `GenerationMixin` from `src/transformers/generation_utils.py` is deprecated and will be removed in Transformers v5. Import as `from transformers import GenerationMixin` instead.
#   warnings.warn(
# Xformers is not installed correctly. If you want to use memory_efficient_attention to accelerate training use the following command to install Xformers
# pip install xformers.
# loading file vocab.txt from cache at /home/tiendat/.cache/huggingface/hub/models--dmis-lab--biobert-base-cased-v1.2/snapshots/67c9c25b46986521ca33df05d8540da1210b3256/vocab.txt
# loading file added_tokens.json from cache at None
# loading file special_tokens_map.json from cache at None
# loading file tokenizer_config.json from cache at None
# loading configuration file config.json from cache at /home/tiendat/.cache/huggingface/hub/models--dmis-lab--biobert-base-cased-v1.2/snapshots/67c9c25b46986521ca33df05d8540da1210b3256/config.json
# Model config BertConfig {
#   "_name_or_path": "dmis-lab/biobert-base-cased-v1.2",
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.30.2",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 28996
# }
#
# Making data from file coNLL_train.txt ...
# Processing 0 rows...
# Processing 5000 rows...
# Processing 10000 rows...
# Processing 15000 rows...
# Processing 20000 rows...
# Processing 25000 rows...
# Processing 30000 rows...
# Processing 35000 rows...
# Processing 40000 rows...
# Processing 45000 rows...
# Processing 50000 rows...
# Processing 55000 rows...
# Processing 60000 rows...
# Processing 65000 rows...
# Processing 70000 rows...
# Processing 75000 rows...
# Processing 80000 rows...
# Processing 85000 rows...
# Processing 90000 rows...
# Processing 95000 rows...
# Processing 100000 rows...
# Processing 105000 rows...
# Processing 110000 rows...
# Processing 115000 rows...
# Processing 120000 rows...
# Processing 125000 rows...
# Processing 130000 rows...
# Processing 135000 rows...
# Processing 140000 rows...
# Processing 145000 rows...
# Processing 150000 rows...
# Processing 155000 rows...
# Processing 160000 rows...
# Processing 165000 rows...
# Processing 170000 rows...
# Processing 175000 rows...
# Processing 180000 rows...
# Processing 185000 rows...
# Processing 190000 rows...
# Processing 195000 rows...
# Processing 200000 rows...
# Processing 205000 rows...
# Processing 210000 rows...
# Processing 215000 rows...
# Processing 220000 rows...
# Processing 225000 rows...
# Processing 230000 rows...
# Processing 235000 rows...
# Processing 240000 rows...
# Processing 245000 rows...
# Processing 250000 rows...
# Processing 255000 rows...
# Processing 260000 rows...
# Processing 265000 rows...
# Processing 270000 rows...
# Processing 275000 rows...
# Processing 280000 rows...
# Processing 285000 rows...
# Processing 290000 rows...
# Processing 295000 rows...
# Processing 300000 rows...
# Processing 305000 rows...
# Processing 310000 rows...
# Processing 315000 rows...
# Processing 320000 rows...
# Processing 325000 rows...
# Processing 330000 rows...
# Processing 335000 rows...
# Processing 340000 rows...
# Processing 345000 rows...
# Processing 350000 rows...
# Processing 355000 rows...
# Processing 360000 rows...
# Processing 365000 rows...
# Processing 370000 rows...
# Processing 375000 rows...
# Processing 380000 rows...
# Processing 385000 rows...
# Processing 390000 rows...
# Processing 395000 rows...
# Processing 400000 rows...
# Processing 405000 rows...
# Processing 410000 rows...
# Processing 415000 rows...
# Processing 420000 rows...
# Processing 425000 rows...
# Processing 430000 rows...
# Processing 435000 rows...
# Processing 440000 rows...
# Processing 445000 rows...
# Processing 450000 rows...
# Processing 455000 rows...
# Processing 460000 rows...
# Processing 465000 rows...
# Processing 470000 rows...
# Processing 475000 rows...
# Processing 480000 rows...
# Processing 485000 rows...
# Processing 490000 rows...
# Processing 495000 rows...
# Processing 500000 rows...
# Processing 505000 rows...
# Processing 510000 rows...
# Processing 515000 rows...
# Processing 520000 rows...
# Processing 525000 rows...
# Processing 530000 rows...
# Processing 535000 rows...
# Processing 540000 rows...
# Processing 545000 rows...
# Processing 550000 rows...
# Processing 555000 rows...
# Processing 560000 rows...
# Processing 565000 rows...
# Processing 570000 rows...
# Processing 575000 rows...
# Processing 580000 rows...
# Processing 585000 rows...
# Processing 590000 rows...
# Processing 595000 rows...
# Processing 600000 rows...
# Processing 605000 rows...
# Processing 610000 rows...
# Processing 615000 rows...
# Processing 620000 rows...
# Processing 625000 rows...
# Processing 630000 rows...
# Processing 635000 rows...
# Processing 640000 rows...
# Processing 645000 rows...
# Processing 650000 rows...
# Processing 655000 rows...
# Processing 660000 rows...
# Processing 665000 rows...
# Processing 670000 rows...
# Processing 675000 rows...
# Processing 680000 rows...
# Processing 685000 rows...
# Processing 690000 rows...
# Processing 695000 rows...
# Processing 700000 rows...
# Processing 705000 rows...
# Processing 710000 rows...
# Processing 715000 rows...
# Processing 720000 rows...
# Processing 725000 rows...
# Processing 730000 rows...
# Processing 735000 rows...
# Processing 740000 rows...
# Processing 745000 rows...
# Processing 750000 rows...
# Processing 755000 rows...
# Processing 760000 rows...
# Processing 765000 rows...
# Processing 770000 rows...
# Processing 775000 rows...
# Processing 780000 rows...
# Processing 785000 rows...
# Processing 790000 rows...
# Processing 795000 rows...
# Processing 800000 rows...
# Processing 805000 rows...
# Processing 810000 rows...
# Processing 815000 rows...
# Processing 820000 rows...
# Processing 825000 rows...
# Processing 830000 rows...
# Processing 835000 rows...
# Processing 840000 rows...
# Processing 845000 rows...
# Processing 850000 rows...
# Processing 855000 rows...
# Processing 860000 rows...
# Processing 865000 rows...
# Processing 870000 rows...
# Processing 875000 rows...
# Processing 880000 rows...
# Processing 885000 rows...
# Processing 890000 rows...
# Processing 895000 rows...
# Processing 900000 rows...
# Processing 905000 rows...
# Processing 910000 rows...
# Processing 915000 rows...
# Processing 920000 rows...
# Processing 925000 rows...
# Processing 930000 rows...
# Processing 935000 rows...
# Processing 940000 rows...
# Processing 945000 rows...
# Processing 950000 rows...
# Processing 955000 rows...
# Processing 960000 rows...
# Processing 965000 rows...
# Processing 970000 rows...
# Processing 975000 rows...
# Processing 980000 rows...
# Processing 985000 rows...
# Processing 990000 rows...
# Processing 995000 rows...
# Processing 1000000 rows...
# Processing 1005000 rows...
# Processing 1010000 rows...
# Processing 1015000 rows...
# Processing 1020000 rows...
# Processing 1025000 rows...
# Processing 1030000 rows...
# Processing 1035000 rows...
# Processing 1040000 rows...
# Processing 1045000 rows...
# Processing 1050000 rows...
# Processing 1055000 rows...
# Processing 1060000 rows...
# Processing 1065000 rows...
# Processing 1070000 rows...
# Processing 1075000 rows...
# Processing 1080000 rows...
# Processing 1085000 rows...
# Processing 1090000 rows...
# Processing 1095000 rows...
# Processing 1100000 rows...
# Processing 1105000 rows...
# Processing 1110000 rows...
# Processing 1115000 rows...
# Processing 1120000 rows...
# Processing 1125000 rows...
# Processing 1130000 rows...
# Processing 1135000 rows...
# Processing 1140000 rows...
# Processing 1145000 rows...
# Processing 1150000 rows...
# Processing 1155000 rows...
# Processing 1160000 rows...
# Processing 1165000 rows...
# Processing 1170000 rows...
# Processing 1175000 rows...
# Processing 1180000 rows...
# Processing 1185000 rows...
# Processing 1190000 rows...
# Processing 1195000 rows...
# Processing 1200000 rows...
# Processing 1205000 rows...
# Processing 1210000 rows...
# Processing 1215000 rows...
# NER File Written at content/data
# POS File Written at content/data
# Created NER label map from train file coNLL_train.txt
# {'B-A1': 0, 'I-A1': 1, 'O': 2, 'B-V': 3, 'B-A0': 4, 'I-A0': 5, 'B-A4': 6, 'I-A4': 7, 'I-A3': 8, 'B-A2': 9, 'I-A2': 10, 'B-A3': 11}
# label Map NER written at content/data/ner_coNLL_train_label_map.joblib
# Created POS label map from train file coNLL_train.txt
# {'B-O': 0}
# label Map POS written at content/data/pos_coNLL_train_label_map.joblib
# Max len of sentence:  83
# Mean len of sentences:  28.17264015333014
# Median len of sentences:  27.0
# Making data from file coNLL_testa.txt ...
# Processing 0 rows...
# Processing 5000 rows...
# Processing 10000 rows...
# Processing 15000 rows...
# Processing 20000 rows...
# Processing 25000 rows...
# Processing 30000 rows...
# Processing 35000 rows...
# Processing 40000 rows...
# Processing 45000 rows...
# Processing 50000 rows...
# Processing 55000 rows...
# Processing 60000 rows...
# Processing 65000 rows...
# Processing 70000 rows...
# Processing 75000 rows...
# Processing 80000 rows...
# Processing 85000 rows...
# Processing 90000 rows...
# Processing 95000 rows...
# Processing 100000 rows...
# Processing 105000 rows...
# Processing 110000 rows...
# Processing 115000 rows...
# Processing 120000 rows...
# Processing 125000 rows...
# Processing 130000 rows...
# Processing 135000 rows...
# Processing 140000 rows...
# Processing 145000 rows...
# Processing 150000 rows...
# Processing 155000 rows...
# Processing 160000 rows...
# Processing 165000 rows...
# Processing 170000 rows...
# Processing 175000 rows...
# Processing 180000 rows...
# Processing 185000 rows...
# Processing 190000 rows...
# Processing 195000 rows...
# Processing 200000 rows...
# Processing 205000 rows...
# Processing 210000 rows...
# Processing 215000 rows...
# Processing 220000 rows...
# Processing 225000 rows...
# Processing 230000 rows...
# Processing 235000 rows...
# Processing 240000 rows...
# Processing 245000 rows...
# Processing 250000 rows...
# Processing 255000 rows...
# Processing 260000 rows...
# Processing 265000 rows...
# NER File Written at content/data
# POS File Written at content/data
# Max len of sentence:  118
# Mean len of sentences:  27.94001304064334
# Median len of sentences:  27.0
# Making data from file coNLL_testb.txt ...
# Processing 0 rows...
# Processing 5000 rows...
# Processing 10000 rows...
# Processing 15000 rows...
# Processing 20000 rows...
# Processing 25000 rows...
# Processing 30000 rows...
# Processing 35000 rows...
# Processing 40000 rows...
# Processing 45000 rows...
# Processing 50000 rows...
# Processing 55000 rows...
# Processing 60000 rows...
# Processing 65000 rows...
# Processing 70000 rows...
# Processing 75000 rows...
# Processing 80000 rows...
# Processing 85000 rows...
# Processing 90000 rows...
# Processing 95000 rows...
# Processing 100000 rows...
# Processing 105000 rows...
# Processing 110000 rows...
# Processing 115000 rows...
# Processing 120000 rows...
# Processing 125000 rows...
# Processing 130000 rows...
# Processing 135000 rows...
# Processing 140000 rows...
# Processing 145000 rows...
# Processing 150000 rows...
# Processing 155000 rows...
# Processing 160000 rows...
# Processing 165000 rows...
# Processing 170000 rows...
# Processing 175000 rows...
# Processing 180000 rows...
# Processing 185000 rows...
# Processing 190000 rows...
# Processing 195000 rows...
# Processing 200000 rows...
# Processing 205000 rows...
# Processing 210000 rows...
# Processing 215000 rows...
# Processing 220000 rows...
# Processing 225000 rows...
# Processing 230000 rows...
# Processing 235000 rows...
# Processing 240000 rows...
# Processing 245000 rows...
# Processing 250000 rows...
# Processing 255000 rows...
# Processing 260000 rows...
# Processing 265000 rows...
# Processing 270000 rows...
# Processing 275000 rows...
# Processing 280000 rows...
# Processing 285000 rows...
# Processing 290000 rows...
# Processing 295000 rows...
# Processing 300000 rows...
# Processing 305000 rows...
# Processing 310000 rows...
# Processing 315000 rows...
# Processing 320000 rows...
# Processing 325000 rows...
# Processing 330000 rows...
# Processing 335000 rows...
# Processing 340000 rows...
# Processing 345000 rows...
# Processing 350000 rows...
# Processing 355000 rows...
# Processing 360000 rows...
# Processing 365000 rows...
# Processing 370000 rows...
# Processing 375000 rows...
# Processing 380000 rows...
# Processing 385000 rows...
# Processing 390000 rows...
# Processing 395000 rows...
# Processing 400000 rows...
# Processing 405000 rows...
# Processing 410000 rows...
# Processing 415000 rows...
# Processing 420000 rows...
# Processing 425000 rows...
# Processing 430000 rows...
# Processing 435000 rows...
# Processing 440000 rows...
# Processing 445000 rows...
# Processing 450000 rows...
# Processing 455000 rows...
# Processing 460000 rows...
# Processing 465000 rows...
# Processing 470000 rows...
# Processing 475000 rows...
# Processing 480000 rows...
# Processing 485000 rows...
# Processing 490000 rows...
# Processing 495000 rows...
# Processing 500000 rows...
# Processing 505000 rows...
# Processing 510000 rows...
# Processing 515000 rows...
# Processing 520000 rows...
# Processing 525000 rows...
# Processing 530000 rows...
# NER File Written at content/data
# POS File Written at content/data
# Max len of sentence:  83
# Mean len of sentences:  27.970335760078235
# Median len of sentences:  27.0
# Making data from file coNLL_testa_abolish.txt ...
# Processing 0 rows...
# Processing 5000 rows...
# NER File Written at content/data
# POS File Written at content/data
# Max len of sentence:  51
# Mean len of sentences:  24.512455516014235
# Median len of sentences:  22
# Making data from file coNLL_testb_abolish.txt ...
# Processing 0 rows...
# Processing 5000 rows...
# NER File Written at content/data
# POS File Written at content/data
# Max len of sentence:  51
# Mean len of sentences:  25.48409893992933
# Median len of sentences:  24
# Making data from file coNLL_testa_alter.txt ...
# Processing 0 rows...
# Processing 5000 rows...
# NER File Written at content/data
# POS File Written at content/data
# Max len of sentence:  34
# Mean len of sentences:  22.03543307086614
# Median len of sentences:  22.0
# Making data from file coNLL_testb_alter.txt ...
# Processing 0 rows...
# Processing 5000 rows...
# NER File Written at content/data
# POS File Written at content/data
# Max len of sentence:  32
# Mean len of sentences:  21.31764705882353
# Median len of sentences:  22
# Making data from file coNLL_testa_begin.txt ...
# Processing 0 rows...
# Processing 5000 rows...
# Processing 10000 rows...
# Processing 15000 rows...
# Processing 20000 rows...
# NER File Written at content/data
# POS File Written at content/data
# Max len of sentence:  52
# Mean len of sentences:  29.80234260614934
# Median len of sentences:  28
# Making data from file coNLL_testb_begin.txt ...
# Processing 0 rows...
# Processing 5000 rows...
# Processing 10000 rows...
# Processing 15000 rows...
# Processing 20000 rows...
# NER File Written at content/data
# POS File Written at content/data
# Max len of sentence:  60
# Mean len of sentences:  29.35233918128655
# Median len of sentences:  28.0
# Making data from file coNLL_testa_block.txt ...
# Processing 0 rows...
# Processing 5000 rows...
# Processing 10000 rows...
# NER File Written at content/data
# POS File Written at content/data
# Max len of sentence:  55
# Mean len of sentences:  30.472375690607734
# Median len of sentences:  31.5
# Making data from file coNLL_testb_block.txt ...
# Processing 0 rows...
# Processing 5000 rows...
# Processing 10000 rows...
# NER File Written at content/data
# POS File Written at content/data
# Max len of sentence:  57
# Mean len of sentences:  30.892561983471076
# Median len of sentences:  30
# Making data from file coNLL_testa_catalyse.txt ...
# Processing 0 rows...
# Processing 5000 rows...
# NER File Written at content/data
# POS File Written at content/data
# Max len of sentence:  82
# Mean len of sentences:  38.00512820512821
# Median len of sentences:  35
# Making data from file coNLL_testb_catalyse.txt ...
# Processing 0 rows...
# Processing 5000 rows...
# NER File Written at content/data
# POS File Written at content/data
# Max len of sentence:  83
# Mean len of sentences:  35.16836734693877
# Median len of sentences:  33.0
# Making data from file coNLL_testa_confer.txt ...
# Processing 0 rows...
# Processing 5000 rows...
# Processing 10000 rows...
# NER File Written at content/data
# POS File Written at content/data
# Max len of sentence:  62
# Mean len of sentences:  32.46056782334385
# Median len of sentences:  32
# Making data from file coNLL_testb_confer.txt ...
# Processing 0 rows...
# Processing 5000 rows...
# Processing 10000 rows...
# NER File Written at content/data
# POS File Written at content/data
# Max len of sentence:  62
# Mean len of sentences:  32.27899686520376
# Median len of sentences:  33
# Making data from file coNLL_testa_decrease.txt ...
# Processing 0 rows...
# Processing 5000 rows...
# NER File Written at content/data
# POS File Written at content/data
# Max len of sentence:  61
# Mean len of sentences:  30.174358974358974
# Median len of sentences:  28
# Making data from file coNLL_testb_decrease.txt ...
# Processing 0 rows...
# Processing 5000 rows...
# NER File Written at content/data
# POS File Written at content/data
# Max len of sentence:  61
# Mean len of sentences:  32.09137055837564
# Median len of sentences:  29
# Making data from file coNLL_testa_delete.txt ...
# Processing 0 rows...
# Processing 5000 rows...
# Processing 10000 rows...
# NER File Written at content/data
# POS File Written at content/data
# Max len of sentence:  48
# Mean len of sentences:  26.124087591240876
# Median len of sentences:  25
# Making data from file coNLL_testb_delete.txt ...
# Processing 0 rows...
# Processing 5000 rows...
# Processing 10000 rows...
# NER File Written at content/data
# POS File Written at content/data
# Max len of sentence:  49
# Mean len of sentences:  25.493946731234868
# Median len of sentences:  24
# Making data from file coNLL_testa_develop.txt ...
# Processing 0 rows...
# NER File Written at content/data
# POS File Written at content/data
# Max len of sentence:  118
# Mean len of sentences:  26.629032258064516
# Median len of sentences:  20.0
# Making data from file coNLL_testb_develop.txt ...
# Processing 0 rows...
# NER File Written at content/data
# POS File Written at content/data
# Max len of sentence:  42
# Mean len of sentences:  26.64516129032258
# Median len of sentences:  20.5
# Making data from file coNLL_testa_disrupt.txt ...
# Processing 0 rows...
# NER File Written at content/data
# POS File Written at content/data
# Max len of sentence:  60
# Mean len of sentences:  29.680672268907564
# Median len of sentences:  26
# Making data from file coNLL_testb_disrupt.txt ...
# Processing 0 rows...
# NER File Written at content/data
# POS File Written at content/data
# Max len of sentence:  58
# Mean len of sentences:  28.75
# Median len of sentences:  25.5
# Making data from file coNLL_testa_eliminate.txt ...
# Processing 0 rows...
# NER File Written at content/data
# POS File Written at content/data
# Max len of sentence:  51
# Mean len of sentences:  22.073298429319372
# Median len of sentences:  17
# Making data from file coNLL_testb_eliminate.txt ...
# Processing 0 rows...
# NER File Written at content/data
# POS File Written at content/data
# Max len of sentence:  52
# Mean len of sentences:  22.84375
# Median len of sentences:  18.0
# Making data from file coNLL_testa_encode.txt ...
# Processing 0 rows...
# NER File Written at content/data
# POS File Written at content/data
# Max len of sentence:  50
# Mean len of sentences:  24.346938775510203
# Median len of sentences:  23.0
# Making data from file coNLL_testb_encode.txt ...
# Processing 0 rows...
# Processing 5000 rows...
# NER File Written at content/data
# POS File Written at content/data
# Max len of sentence:  50
# Mean len of sentences:  24.568527918781726
# Median len of sentences:  24
# Making data from file coNLL_testa_express.txt ...
# Processing 0 rows...
# Processing 5000 rows...
# Processing 10000 rows...
# NER File Written at content/data
# POS File Written at content/data
# Max len of sentence:  42
# Mean len of sentences:  26.08607594936709
# Median len of sentences:  26
# Making data from file coNLL_testb_express.txt ...
# Processing 0 rows...
# Processing 5000 rows...
# Processing 10000 rows...
# NER File Written at content/data
# POS File Written at content/data
# Max len of sentence:  45
# Mean len of sentences:  25.83123425692695
# Median len of sentences:  26
# Making data from file coNLL_testa_generate.txt ...
# Processing 0 rows...
# Processing 5000 rows...
# Processing 10000 rows...
# NER File Written at content/data
# POS File Written at content/data
# Max len of sentence:  56
# Mean len of sentences:  26.991891891891893
# Median len of sentences:  24.0
# Making data from file coNLL_testb_generate.txt ...
# Processing 0 rows...
# Processing 5000 rows...
# Processing 10000 rows...
# NER File Written at content/data
# POS File Written at content/data
# Max len of sentence:  56
# Mean len of sentences:  27.26145552560647
# Median len of sentences:  24
# Making data from file coNLL_testa_inhibit.txt ...
# Processing 0 rows...
# Processing 5000 rows...
# Processing 10000 rows...
# NER File Written at content/data
# POS File Written at content/data
# Max len of sentence:  79
# Mean len of sentences:  29.383480825958703
# Median len of sentences:  27
# Making data from file coNLL_testb_inhibit.txt ...
# Processing 0 rows...
# Processing 5000 rows...
# Processing 10000 rows...
# NER File Written at content/data
# POS File Written at content/data
# Max len of sentence:  80
# Mean len of sentences:  28.926686217008797
# Median len of sentences:  27
# Making data from file coNLL_testa_initiate.txt ...
# Processing 0 rows...
# Processing 5000 rows...
# NER File Written at content/data
# POS File Written at content/data
# Max len of sentence:  64
# Mean len of sentences:  31.65989847715736
# Median len of sentences:  28
# Making data from file coNLL_testb_initiate.txt ...
# Processing 0 rows...
# Processing 5000 rows...
# NER File Written at content/data
# POS File Written at content/data
# Max len of sentence:  62
# Mean len of sentences:  31.17766497461929
# Median len of sentences:  28
# Making data from file coNLL_testa_lead.txt ...
# Processing 0 rows...
# Processing 5000 rows...
# Processing 10000 rows...
# Processing 15000 rows...
# NER File Written at content/data
# POS File Written at content/data
# Max len of sentence:  77
# Mean len of sentences:  31.428861788617887
# Median len of sentences:  29.0
# Making data from file coNLL_testb_lead.txt ...
# Processing 0 rows...
# Processing 5000 rows...
# Processing 10000 rows...
# Processing 15000 rows...
# NER File Written at content/data
# POS File Written at content/data
# Max len of sentence:  77
# Mean len of sentences:  31.39553752535497
# Median len of sentences:  29
# Making data from file coNLL_testa_lose.txt ...
# Processing 0 rows...
# Processing 5000 rows...
# NER File Written at content/data
# POS File Written at content/data
# Max len of sentence:  57
# Mean len of sentences:  29.1013986013986
# Median len of sentences:  30.0
# Making data from file coNLL_testb_lose.txt ...
# Processing 0 rows...
# Processing 5000 rows...
# NER File Written at content/data
# POS File Written at content/data
# Max len of sentence:  56
# Mean len of sentences:  28.209059233449477
# Median len of sentences:  29
# Making data from file coNLL_testa_modify.txt ...
# Processing 0 rows...
# Processing 5000 rows...
# NER File Written at content/data
# POS File Written at content/data
# Max len of sentence:  51
# Mean len of sentences:  32.78313253012048
# Median len of sentences:  30.0
# Making data from file coNLL_testb_modify.txt ...
# Processing 0 rows...
# Processing 5000 rows...
# NER File Written at content/data
# POS File Written at content/data
# Max len of sentence:  48
# Mean len of sentences:  32.65868263473054
# Median len of sentences:  31
# Making data from file coNLL_testa_mutate.txt ...
# Processing 0 rows...
# Processing 5000 rows...
# NER File Written at content/data
# POS File Written at content/data
# Max len of sentence:  55
# Mean len of sentences:  31.75
# Median len of sentences:  32.0
# Making data from file coNLL_testb_mutate.txt ...
# Processing 0 rows...
# Processing 5000 rows...
# NER File Written at content/data
# POS File Written at content/data
# Max len of sentence:  56
# Mean len of sentences:  33.46122448979592
# Median len of sentences:  32
# Making data from file coNLL_testa_proliferate.txt ...
# Processing 0 rows...
# NER File Written at content/data
# POS File Written at content/data
# Max len of sentence:  44
# Mean len of sentences:  26.820987654320987
# Median len of sentences:  24.5
# Making data from file coNLL_testb_proliferate.txt ...
# Processing 0 rows...
# NER File Written at content/data
# POS File Written at content/data
# Max len of sentence:  43
# Mean len of sentences:  26.312883435582823
# Median len of sentences:  24
# Making data from file coNLL_testa_recognize.txt ...
# Processing 0 rows...
# Processing 5000 rows...
# NER File Written at content/data
# POS File Written at content/data
# Max len of sentence:  61
# Mean len of sentences:  25.83848797250859
# Median len of sentences:  23
# Making data from file coNLL_testb_recognize.txt ...
# Processing 0 rows...
# Processing 5000 rows...
# NER File Written at content/data
# POS File Written at content/data
# Max len of sentence:  53
# Mean len of sentences:  24.600682593856654
# Median len of sentences:  21
# Making data from file coNLL_testa_result.txt ...
# Processing 0 rows...
# Processing 5000 rows...
# Processing 10000 rows...
# NER File Written at content/data
# POS File Written at content/data
# Max len of sentence:  53
# Mean len of sentences:  28.45766129032258
# Median len of sentences:  28.0
# Making data from file coNLL_testb_result.txt ...
# Processing 0 rows...
# Processing 5000 rows...
# Processing 10000 rows...
# NER File Written at content/data
# POS File Written at content/data
# Max len of sentence:  52
# Mean len of sentences:  27.561368209255534
# Median len of sentences:  27
# Making data from file coNLL_testa_skip.txt ...
# Processing 0 rows...
# NER File Written at content/data
# POS File Written at content/data
# Max len of sentence:  69
# Mean len of sentences:  32.962025316455694
# Median len of sentences:  28
# Making data from file coNLL_testb_skip.txt ...
# Processing 0 rows...
# NER File Written at content/data
# POS File Written at content/data
# Max len of sentence:  70
# Mean len of sentences:  31.525
# Median len of sentences:  28.5
# Making data from file coNLL_testa_splice.txt ...
# Processing 0 rows...
# Processing 5000 rows...
# Processing 10000 rows...
# NER File Written at content/data
# POS File Written at content/data
# Max len of sentence:  57
# Mean len of sentences:  29.325641025641026
# Median len of sentences:  24.5
# Making data from file coNLL_testb_splice.txt ...
# Processing 0 rows...
# Processing 5000 rows...
# Processing 10000 rows...
# NER File Written at content/data
# POS File Written at content/data
# Max len of sentence:  57
# Mean len of sentences:  28.307692307692307
# Median len of sentences:  23.0
# Making data from file coNLL_testa_transcribe.txt ...
# Processing 0 rows...
# Processing 5000 rows...
# Processing 10000 rows...
# Processing 15000 rows...
# Processing 20000 rows...
# NER File Written at content/data
# POS File Written at content/data
# Max len of sentence:  50
# Mean len of sentences:  24.774718397997496
# Median len of sentences:  24
# Making data from file coNLL_testb_transcribe.txt ...
# Processing 0 rows...
# Processing 5000 rows...
# Processing 10000 rows...
# Processing 15000 rows...
# Processing 20000 rows...
# NER File Written at content/data
# POS File Written at content/data
# Max len of sentence:  50
# Mean len of sentences:  24.928838951310862
# Median len of sentences:  24
# Making data from file coNLL_testa_transform.txt ...
# Processing 0 rows...
# Processing 5000 rows...
# NER File Written at content/data
# POS File Written at content/data
# Max len of sentence:  40
# Mean len of sentences:  22.544
# Median len of sentences:  22
# Making data from file coNLL_testb_transform.txt ...
# Processing 0 rows...
# Processing 5000 rows...
# NER File Written at content/data
# POS File Written at content/data
# Max len of sentence:  39
# Mean len of sentences:  22.3262599469496
# Median len of sentences:  22
# Making data from file coNLL_testa_translate.txt ...
# Processing 0 rows...
# Processing 5000 rows...
# Processing 10000 rows...
# Processing 15000 rows...
# NER File Written at content/data
# POS File Written at content/data
# Max len of sentence:  61
# Mean len of sentences:  26.696165191740413
# Median len of sentences:  24.0
# Making data from file coNLL_testb_translate.txt ...
# Processing 0 rows...
# Processing 5000 rows...
# Processing 10000 rows...
# Processing 15000 rows...
# NER File Written at content/data
# POS File Written at content/data
# Max len of sentence:  61
# Mean len of sentences:  26.290560471976402
# Median len of sentences:  24.0
# Making data from file coNLL_testa_truncate.txt ...
# Processing 0 rows...
# Processing 5000 rows...
# NER File Written at content/data
# POS File Written at content/data
# Max len of sentence:  56
# Mean len of sentences:  35.1055900621118
# Median len of sentences:  37
# Making data from file coNLL_testb_truncate.txt ...
# Processing 0 rows...
# Processing 5000 rows...
# NER File Written at content/data
# POS File Written at content/data
# Max len of sentence:  55
# Mean len of sentences:  35.962732919254655
# Median len of sentences:  37
# Making data from file coNLL_train1.txt ...
# Processing 0 rows...
# Processing 5000 rows...
# Processing 10000 rows...
# Processing 15000 rows...
# Processing 20000 rows...
# Processing 25000 rows...
# Processing 30000 rows...
# Processing 35000 rows...
# Processing 40000 rows...
# Processing 45000 rows...
# Processing 50000 rows...
# Processing 55000 rows...
# Processing 60000 rows...
# Processing 65000 rows...
# Processing 70000 rows...
# Processing 75000 rows...
# Processing 80000 rows...
# Processing 85000 rows...
# Processing 90000 rows...
# Processing 95000 rows...
# Processing 100000 rows...
# Processing 105000 rows...
# Processing 110000 rows...
# Processing 115000 rows...
# Processing 120000 rows...
# Processing 125000 rows...
# Processing 130000 rows...
# Processing 135000 rows...
# Processing 140000 rows...
# Processing 145000 rows...
# Processing 150000 rows...
# Processing 155000 rows...
# Processing 160000 rows...
# Processing 165000 rows...
# Processing 170000 rows...
# Processing 175000 rows...
# Processing 180000 rows...
# Processing 185000 rows...
# Processing 190000 rows...
# Processing 195000 rows...
# Processing 200000 rows...
# Processing 205000 rows...
# Processing 210000 rows...
# Processing 215000 rows...
# Processing 220000 rows...
# Processing 225000 rows...
# Processing 230000 rows...
# Processing 235000 rows...
# Processing 240000 rows...
# Processing 245000 rows...
# Processing 250000 rows...
# Processing 255000 rows...
# Processing 260000 rows...
# Processing 265000 rows...
# Processing 270000 rows...
# Processing 275000 rows...
# Processing 280000 rows...
# Processing 285000 rows...
# Processing 290000 rows...
# Processing 295000 rows...
# Processing 300000 rows...
# Processing 305000 rows...
# Processing 310000 rows...
# Processing 315000 rows...
# Processing 320000 rows...
# Processing 325000 rows...
# Processing 330000 rows...
# Processing 335000 rows...
# Processing 340000 rows...
# Processing 345000 rows...
# Processing 350000 rows...
# Processing 355000 rows...
# Processing 360000 rows...
# Processing 365000 rows...
# Processing 370000 rows...
# Processing 375000 rows...
# Processing 380000 rows...
# Processing 385000 rows...
# Processing 390000 rows...
# NER File Written at content/data
# POS File Written at content/data
# Created NER label map from train file coNLL_train1.txt
# {'B-amod_2': 0, 'B-nsubjpass_4': 1, 'B-auxpass_4': 2, 'B-root_0': 3, 'B-prep_4': 4, 'B-nn_10': 5, 'I-nn_10': 6, 'B-pobj_5': 7, 'B-prep_10': 8, 'B-amod_15': 9, 'B-nn_15': 10, 'I-nn_15': 11, 'B-pobj_11': 12, 'B-punct_4': 13, 'B-nsubjpass_13': 14, 'B-prep_1': 15, 'B-det_6': 16, 'B-amod_6': 17, 'B-dep_4': 18, 'B-pobj_2': 19, 'B-prep_6': 20, 'B-amod_10': 21, 'B-pobj_7': 22, 'B-aux_13': 23, 'B-auxpass_13': 24, 'B-prep_13': 25, 'B-amod_16': 26, 'B-pobj_14': 27, 'B-punct_13': 28, 'B-nsubjpass_17': 29, 'B-nn_6': 30, 'I-nn_6': 31, 'B-num_6': 32, 'B-cc_6': 33, 'B-conj_6': 34, 'B-prep_8': 35, 'B-det_11': 36, 'B-pobj_9': 37, 'B-dep_11': 38, 'B-cc_12': 39, 'B-conj_12': 40, 'B-aux_17': 41, 'B-auxpass_17': 42, 'B-prep_17': 43, 'B-det_20': 44, 'B-pobj_18': 45, 'B-punct_17': 46, 'B-mark_6': 47, 'B-nn_5': 48, 'I-nn_5': 49, 'B-num_5': 50, 'B-nsubj_6': 51, 'B-advcl_18': 52, 'B-dobj_6': 53, 'B-nn_11': 54, 'I-nn_11': 55, 'B-pobj_8': 56, 'B-appos_11': 57, 'I-punct_18': 58, 'B-nsubj_18': 59, 'B-aux_18': 60, 'B-prep_18': 61, 'B-det_22': 62, 'B-nn_22': 63, 'B-pobj_19': 64, 'B-vmod_22': 65, 'B-prep_23': 66, 'B-det_26': 67, 'B-pobj_24': 68, 'B-prep_26': 69, 'B-amod_29': 70, 'B-pobj_27': 71, 'B-punct_18': 72, 'B-det_2': 73, 'B-nsubjpass_36': 74, 'B-prep_2': 75, 'B-nn_7': 76, 'I-nn_7': 77, 'B-pobj_3': 78, 'B-punct_9': 79, 'B-appos_7': 80, 'I-punct_2': 81, 'B-nsubj_15': 82, 'B-prep_12': 83, 'B-pobj_13': 84, 'B-rcmod_2': 85, 'B-prep_15': 86, 'B-amod_22': 87, 'I-nn_22': 88, 'B-pobj_16': 89, 'B-num_22': 90, 'B-cc_15': 91, 'B-conj_15': 92, 'B-det_32': 93, 'B-nn_32': 94, 'I-nn_32': 95, 'B-num_32': 96, 'B-punct_2': 97, 'B-aux_36': 98, 'B-auxpass_36': 99, 'B-punct_36': 100, 'B-vmod_36': 101, 'B-nsubj_43': 102, 'B-aux_43': 103, 'B-cop_43': 104, 'B-amod_43': 105, 'B-ccomp_38': 106, 'B-prep_43': 107, 'B-det_47': 108, 'B-amod_47': 109, 'B-pobj_44': 110, 'B-prep_47': 111, 'B-det_52': 112, 'B-nn_52': 113, 'I-nn_52': 114, 'B-pobj_48': 115, 'B-det_3': 116, 'B-nn_3': 117, 'B-nsubj_4': 118, 'B-num_7': 119, 'B-prep_7': 120, 'B-prep_9': 121, 'B-nn_12': 122, 'B-pobj_10': 123, 'B-punct_7': 124, 'B-num_15': 125, 'B-conj_7': 126, 'B-amod_18': 127, 'B-vmod_18': 128, 'B-dobj_19': 129, 'B-dep_20': 130, 'B-cc_7': 131, 'B-quantmod_25': 132, 'B-num_26': 133, 'B-det_29': 134, 'B-vmod_29': 135, 'B-dep_32': 136, 'B-dobj_30': 137, 'B-punct_34': 138, 'B-dep_29': 139, 'B-amod_34': 140, 'B-dep_35': 141, 'I-punct_4': 142, 'B-amod_3': 143, 'B-nsubj_10': 144, 'B-prep_3': 145, 'B-pobj_4': 146, 'B-nn_9': 147, 'B-mark_18': 148, 'B-det_13': 149, 'B-cop_18': 150, 'B-neg_18': 151, 'B-nn_18': 152, 'I-nn_18': 153, 'B-ccomp_10': 154, 'B-cc_18': 155, 'B-advmod_24': 156, 'B-cop_24': 157, 'B-amod_24': 158, 'B-conj_18': 159, 'B-prep_24': 160, 'B-nn_27': 161, 'B-pobj_25': 162, 'B-poss_29': 163, 'B-nsubjpass_31': 164, 'B-auxpass_31': 165, 'B-rcmod_27': 166, 'B-prep_31': 167, 'B-det_34': 168, 'B-pobj_32': 169, 'B-prep_34': 170, 'B-amod_37': 171, 'B-pobj_35': 172, 'B-punct_10': 173, 'B-nsubj_20': 174, 'B-det_8': 175, 'B-cc_8': 176, 'B-nn_13': 177, 'I-nn_13': 178, 'B-num_13': 179, 'B-conj_8': 180, 'B-advmod_15': 181, 'B-vmod_8': 182, 'B-det_19': 183, 'B-amod_19': 184, 'B-dobj_20': 185, 'B-punct_20': 186, 'B-vmod_20': 187, 'B-mark_32': 188, 'B-nsubj_32': 189, 'B-prep_28': 190, 'B-det_31': 191, 'B-pobj_29': 192, 'B-ccomp_24': 193, 'B-prep_32': 194, 'B-pobj_33': 195, 'B-det_9': 196, 'B-amod_9': 197, 'I-amod_9': 198, 'B-punct_1': 199, 'B-prep_5': 200, 'B-pobj_1': 201, 'B-nsubj_5': 202, 'B-dobj_5': 203, 'B-punct_11': 204, 'B-cc_14': 205, 'I-cc_11': 206, 'B-conj_11': 207, 'B-punct_5': 208, 'B-det_23': 209, 'B-nn_23': 210, 'B-amod_23': 211, 'I-amod_23': 212, 'B-dep_23': 213, 'B-amod_4': 214, 'B-dobj_1': 215, 'B-nsubj_9': 216, 'B-parataxis_1': 217, 'B-det_12': 218, 'B-amod_12': 219, 'B-dobj_9': 220, 'B-num_17': 221, 'B-conj_14': 222, 'B-punct_19': 223, 'B-dep_17': 224, 'B-cc_19': 225, 'B-conj_19': 226, 'B-appos_19': 227, 'B-dep_24': 228, 'B-nn_29': 229, 'B-mark_49': 230, 'B-advmod_33': 231, 'B-num_36': 232, 'B-cc_33': 233 ...
# label Map NER written at content/data/ner_coNLL_train1_label_map.joblib
# Created POS label map from train file coNLL_train1.txt
# {'_': 0}
# label Map POS written at content/data/pos_coNLL_train1_label_map.joblib
# Max len of sentence:  164
# Mean len of sentences:  26.269321656936334
# Median len of sentences:  24.0
# Making data from file coNLL_testa1.txt ...
# Processing 0 rows...
# Processing 5000 rows...
# Processing 10000 rows...
# Processing 15000 rows...
# Processing 20000 rows...
# Processing 25000 rows...
# Processing 30000 rows...
# Processing 35000 rows...
# NER File Written at content/data
# POS File Written at content/data
# Max len of sentence:  65
# Mean len of sentences:  25.80722891566265
# Median len of sentences:  24.0
# Making data from file coNLL_testb1.txt ...
# Processing 0 rows...
# Processing 5000 rows...
# Processing 10000 rows...
# Processing 15000 rows...
# Processing 20000 rows...
# Processing 25000 rows...
# Processing 30000 rows...
# Processing 35000 rows...
# NER File Written at content/data
# POS File Written at content/data
# Max len of sentence:  67
# Mean len of sentences:  25.517319277108435
# Median len of sentences:  24.0
# Making data from file coNLL_testb1_dummy.txt ...
# Processing 0 rows...
# Processing 5000 rows...
# Processing 10000 rows...
# NER File Written at content/data
# POS File Written at content/data
# Max len of sentence:  59
# Mean len of sentences:  25.305555555555557
# Median len of sentences:  24.0
# Making data from file coNLL_train2.txt ...
# Processing 0 rows...
# Processing 5000 rows...
# Processing 10000 rows...
# Processing 15000 rows...
# Processing 20000 rows...
# Processing 25000 rows...
# Processing 30000 rows...
# Processing 35000 rows...
# Processing 40000 rows...
# Processing 45000 rows...
# Processing 50000 rows...
# Processing 55000 rows...
# Processing 60000 rows...
# Processing 65000 rows...
# Processing 70000 rows...
# Processing 75000 rows...
# Processing 80000 rows...
# Processing 85000 rows...
# Processing 90000 rows...
# Processing 95000 rows...
# Processing 100000 rows...
# Processing 105000 rows...
# Processing 110000 rows...
# Processing 115000 rows...
# Processing 120000 rows...
# Processing 125000 rows...
# Processing 130000 rows...
# Processing 135000 rows...
# Processing 140000 rows...
# Processing 145000 rows...
# Processing 150000 rows...
# Processing 155000 rows...
# Processing 160000 rows...
# Processing 165000 rows...
# Processing 170000 rows...
# Processing 175000 rows...
# Processing 180000 rows...
# Processing 185000 rows...
# Processing 190000 rows...
# Processing 195000 rows...
# Processing 200000 rows...
# Processing 205000 rows...
# Processing 210000 rows...
# Processing 215000 rows...
# Processing 220000 rows...
# Processing 225000 rows...
# Processing 230000 rows...
# Processing 235000 rows...
# Processing 240000 rows...
# Processing 245000 rows...
# Processing 250000 rows...
# Processing 255000 rows...
# Processing 260000 rows...
# Processing 265000 rows...
# Processing 270000 rows...
# Processing 275000 rows...
# Processing 280000 rows...
# Processing 285000 rows...
# Processing 290000 rows...
# Processing 295000 rows...
# Processing 300000 rows...
# Processing 305000 rows...
# Processing 310000 rows...
# Processing 315000 rows...
# Processing 320000 rows...
# Processing 325000 rows...
# Processing 330000 rows...
# Processing 335000 rows...
# Processing 340000 rows...
# Processing 345000 rows...
# Processing 350000 rows...
# Processing 355000 rows...
# Processing 360000 rows...
# Processing 365000 rows...
# Processing 370000 rows...
# Processing 375000 rows...
# Processing 380000 rows...
# Processing 385000 rows...
# Processing 390000 rows...
# Processing 395000 rows...
# Processing 400000 rows...
# Processing 405000 rows...
# Processing 410000 rows...
# Processing 415000 rows...
# Processing 420000 rows...
# Processing 425000 rows...
# Processing 430000 rows...
# Processing 435000 rows...
# Processing 440000 rows...
# Processing 445000 rows...
# Processing 450000 rows...
# Processing 455000 rows...
# Processing 460000 rows...
# Processing 465000 rows...
# Processing 470000 rows...
# Processing 475000 rows...
# Processing 480000 rows...
# Processing 485000 rows...
# Processing 490000 rows...
# Processing 495000 rows...
# Processing 500000 rows...
# Processing 505000 rows...
# Processing 510000 rows...
# Processing 515000 rows...
# Processing 520000 rows...
# Processing 525000 rows...
# Processing 530000 rows...
# Processing 535000 rows...
# Processing 540000 rows...
# Processing 545000 rows...
# Processing 550000 rows...
# Processing 555000 rows...
# Processing 560000 rows...
# Processing 565000 rows...
# Processing 570000 rows...
# Processing 575000 rows...
# Processing 580000 rows...
# Processing 585000 rows...
# Processing 590000 rows...
# Processing 595000 rows...
# Processing 600000 rows...
# Processing 605000 rows...
# Processing 610000 rows...
# Processing 615000 rows...
# Processing 620000 rows...
# Processing 625000 rows...
# NER File Written at content/data
# POS File Written at content/data
# Created NER label map from train file coNLL_train2.txt
# {'B-S_NP_NP_NN': 0, 'B-NN': 1, 'O-NP': 2, 'B-PP_IN': 3, 'B-NP_DT': 4, 'O-PP': 5, 'B-VP_VBZ': 6, 'B-VP_VBN': 7, 'B-NP_PP_IN': 8, 'B-NP_NP_NN': 9, 'O-VP': 10, 'B-PERIOD': 11, 'O-S': 12, 'B-S_NP_NN': 13, 'B-NNS': 14, 'B-VP_VBP': 15, 'B-NP_NP_JJ': 16, 'B-SBAR_WHNP_WDT': 17, 'O-WHNP': 18, 'B-S_NP_VP_VBP': 19, 'B-VBG': 20, 'B-SBAR_WHNP_S_NP_VP_O-SBAR': 21, 'O-SBAR': 22, 'B-S_NP_NP_DT': 23, 'B-JJ': 24, 'B-NP_NN': 25, 'B-RB': 26, 'B-VP_VB': 27, 'B-NP_NP_NNS': 28, 'B-COMMA': 29, 'B-SBAR_IN': 30, 'B-NP_ADVP_FW': 31, 'B-FW': 32, 'O-ADVP': 33, 'B-NP_JJ': 34, 'B-S_ADVP_RB': 35, 'B-NP_NP_DT': 36, 'B-S_PP_IN': 37, 'B-NP_NP_PP_O-PP': 38, 'B-NP_VP_VBD': 39, 'B-S_NP_VP_TO': 40, 'B-CC': 41, 'B-PRN_LRB': 42, 'B-NP_NNS': 43, 'B-RRB': 44, 'O-PRN': 45, 'B-VP_VBD': 46, 'B-NP_O-VP': 47, 'B-S_S_NP_DT': 48, 'B-ADJP_ADJP_RB': 49, 'B-JJR': 50, 'O-ADJP': 51, 'B-PP_O-ADJP': 52, 'B-COLON': 53, 'B-NP_NP_CD': 54, 'B-S_NP_NP_NP_DT': 55, 'B-S_NP_VP_VBG': 56, 'B-S_S_NP_NP_DT': 57, 'B-NP_O-NP': 58, 'B-NP_PP_O-VP': 59, 'B-S_SBAR_WHADVP_WRB': 60, 'O-WHADVP': 61, 'B-S_NP_VP_O-SBAR': 62, 'B-S_NP_CC': 63, 'B-NP_NP_PP_PP_CC': 64, 'B-NP_NP_PP_PP_O-NP': 65, 'B-ADJP_RB': 66, 'B-S_NP_NP_ADJP_JJ': 67, 'B-S_NP_PRP': 68, 'B-ADVP_RB': 69, 'B-ADJP_NN': 70, 'B-VP_VP_VBP': 71, 'B-VP_MD': 72, 'B-NP_NP_NP_NN': 73, 'B-NP_PP_PP_IN': 74, 'B-CONJP_CC': 75, 'O-CONJP': 76, 'B-NP_ADJP_ADJP_JJ': 77, 'B-ADJP_JJ': 78, 'B-PP_TO': 79, 'B-S_NP_VP_MD': 80, 'B-VP_VP_VBD': 81, 'B-NP_NP_PP_O-VP': 82, 'B-S_S_NP_NP_NN': 83, 'B-S_NP_VP_VP_VBZ': 84, 'B-PP_O-VP': 85, 'B-S_NP_DT': 86, 'B-NP_NP_NP_DT': 87, 'B-ADJP_ADJP_NN': 88, 'B-ADJP_O-ADJP': 89, 'B-VP_VBG': 90, 'B-S_NP_NP_JJ': 91, 'B-S_NP_NP_NP_NN': 92, 'B-S_SBAR_IN': 93, 'B-S_S_NP_VP_TO': 94, 'B-NP_PRP': 95, 'B-NP_NP_COMMA': 96, 'B-NP_O-PP': 97, 'B-S_NP_VBG': 98, 'B-NP_ADVP_RB': 99, 'B-NP_CD': 100, 'B-S_S_NP_VP_VBG': 101, 'B-TO': 102, 'B-PP_JJ': 103, 'B-NP_NP_CC': 104, 'B-DT': 105, 'B-S_NP_NP_NP_JJ': 106, 'B-NP_NP_NP_JJ': 107, 'B-NP_NP_VBN': 108, 'B-NP_RRB': 109, 'B-S_NP_VP_VBZ': 110, 'B-NP_NP_ADJP_ADJP_VBN': 111, 'B-VP_VP_VBN': 112, 'B-NP_ADVP_ADVP_RB': 113, 'B-NP_QP_CD': 114, 'O-QP': 115, 'B-LQT': 116, 'B-RQT': 117, 'B-NP_LQT': 118, 'B-IN': 119, 'B-VBN': 120, 'B-UCP_ADJP_JJ': 121, 'B-ADJP_VBN': 122, 'O-UCP': 123, 'B-PP_NP_CD': 124, 'B-S_NP_ADJP_JJ': 125, 'B-PP_O-S': 126, 'B-ADVP_FW': 127, 'B-NP_ADJP_RB': 128, 'B-NP_NP_PRN_NP_O-NP': 129, 'B-S_NP_NP_NNS': 130, 'B-NP_S_NP_VP_VBG': 131, 'B-NP_NP_QP_CD': 132, 'B-CD': 133, 'B-LRB': 134, 'B-NP_NP_NP_ADJP_CD': 135, 'B-NP_QP_JJR': 136, 'B-NP_NP_NP_NNS': 137, 'B-NP_ADJP_NN': 138, 'B-NP_JJR': 139, 'B-S_S_PP_IN': 140, 'B-NP_NP_ADJP_RB': 141, 'B-PP_ADVP_RB': 142, 'B-S_S_S_NP_JJ': 143, 'B-S_NP_JJ': 144, 'B-PP_O-NP': 145, 'B-NP_PRPP': 146, 'B-S_PP_NP_CD': 147, 'B-NP_NP_NP_PRN_COMMA': 148, 'B-NP_VBN': 149, 'B-S_NP_VP_VBN': 150, 'B-ADVP_O-VP': 151, 'B-NP_NP_ADJP_ADJP_JJ': 152, 'B-NP_NP_QP_RB': 153, 'B-VP_O-S': 154, 'B-VP_ADVP_RB': 155, 'B-NP_COMMA': 156, 'B-NP_CC': 157, 'B-ADJP_ADJP_JJ': 158, 'B-ADJP_VBG': 159, 'B-VP_TO': 160, 'B-NP_NP_ADJP_ADJP_CC': 161, 'B-NP_NP_PP_PP_O-PP': 162, 'B-S_S_NP_ADJP_RB': 163, 'B-PP_VBN': 164, 'B-NP_PRN_LRB': 165, 'B-NP_ADJP_QP_CD': 166, 'B-S_NP_NNS': 167, 'B-S_NP_NP_PRPP': 168, 'B-NP_ADJP_CC': 169, 'B-S_NP_VP_VB': 170, 'B-VP_ADVP_VB': 171, 'B-S_NP_ADJP_RB': 172, 'B-S_O-NP': 173, 'B-NP_PP_TO': 174, 'B-VB': 175, 'B-NP_NP_NP_NP_DT': 176, 'B-S_NP_NP_CD': 177, 'B-ADJP_O-VP': 178, 'B-SBAR_WHPP_IN': 179, 'B-WHNP_WDT': 180, 'O-WHPP': 181, 'B-S_NP_NP_VBG': 182, 'B-NP_EX': 183, 'B-SBAR_WHADVP_S_NP_VP_TO': 184, 'B-NP_S_NP_VP_TO': 185, 'B-NP_VP_VBG': 186, 'B-NP_PP_O-NP': 187, 'B-S_S_LST_LRB': 188, 'B-LS': 189, 'O-LST': 190, 'B-NP_NP_VP_O-PP': 191, 'B-S_LST_LRB': 192, 'B-ADJP_ADJP_VBN': 193, 'B-ADJP_ADJP_RBR': 194, 'B-NP_O-ADJP': 195, 'B-S_S_NP_NN': 196, 'B-NP_ADJP_ADJP_CC': 197, 'B-ADJP_NNS': 198, 'B-PP_NP_RB': 199, 'B-NP_NP_NP_CD': 200, 'B-PP_NP_JJ': 201, 'B-PP_PP_IN': 202, 'B-S_NP_VP_ADVP_RB': 203, 'B-VBD': 204, 'B-NP_NP_NP_NP_NN': 205, 'B-NP_NP_NP_VBG': 206, 'B-CONJP_RB': 207, 'B-S_NP_PRPP': 208 ...
# label Map NER written at content/data/ner_coNLL_train2_label_map.joblib
# Created POS label map from train file coNLL_train2.txt
# {'B-O': 0}
# label Map POS written at content/data/pos_coNLL_train2_label_map.joblib
# Max len of sentence:  230
# Mean len of sentences:  44.89218704192319
# Median len of sentences:  41.0
# Making data from file coNLL_testa2.txt ...
# Processing 0 rows...
# Processing 5000 rows...
# Processing 10000 rows...
# Processing 15000 rows...
# Processing 20000 rows...
# Processing 25000 rows...
# Processing 30000 rows...
# Processing 35000 rows...
# Processing 40000 rows...
# Processing 45000 rows...
# Processing 50000 rows...
# Processing 55000 rows...
# Processing 60000 rows...
# Processing 65000 rows...
# Processing 70000 rows...
# Processing 75000 rows...
# Processing 80000 rows...
# Processing 85000 rows...
# Processing 90000 rows...
# Processing 95000 rows...
# Processing 100000 rows...
# Processing 105000 rows...
# Processing 110000 rows...
# Processing 115000 rows...
# Processing 120000 rows...
# Processing 125000 rows...
# Processing 130000 rows...
# Processing 135000 rows...
# Processing 140000 rows...
# NER File Written at content/data
# POS File Written at content/data
# Max len of sentence:  176
# Mean len of sentences:  44.93237639553429
# Median len of sentences:  42
# Making data from file coNLL_testb2.txt ...
# Processing 0 rows...
# Processing 5000 rows...
# Processing 10000 rows...
# Processing 15000 rows...
# Processing 20000 rows...
# Processing 25000 rows...
# Processing 30000 rows...
# Processing 35000 rows...
# Processing 40000 rows...
# Processing 45000 rows...
# Processing 50000 rows...
# Processing 55000 rows...
# Processing 60000 rows...
# Processing 65000 rows...
# Processing 70000 rows...
# Processing 75000 rows...
# Processing 80000 rows...
# Processing 85000 rows...
# Processing 90000 rows...
# Processing 95000 rows...
# Processing 100000 rows...
# Processing 105000 rows...
# Processing 110000 rows...
# Processing 115000 rows...
# Processing 120000 rows...
# Processing 125000 rows...
# Processing 130000 rows...
# Processing 135000 rows...
# Processing 140000 rows...
# Processing 145000 rows...
# Processing 150000 rows...
# Processing 155000 rows...
# NER File Written at content/data
# POS File Written at content/data
# Max len of sentence:  150
# Mean len of sentences:  44.45361428153351
# Median len of sentences:  41
# Making data from file coNLL_testb2_dummy.txt ...
# Processing 0 rows...
# Processing 5000 rows...
# Processing 10000 rows...
# NER File Written at content/data
# POS File Written at content/data
# Max len of sentence:  125
# Mean len of sentences:  46.00396825396825
# Median len of sentences:  42.0

# %% [markdown]
# # Step -2 Data Preparation
#
# For more details on the data preparation process, refer to <a href="https://multi-task-nlp.readthedocs.io/en/latest/training.html#running-data-preparation">data preparation</a> in documentation.
#
# Defining tasks file for training single model for entailment task. The file is already created at ``tasks_file_conll.yml``
# ```
# conllner:
#   model_type: BERT
#   config_name: bert-base-uncased
#   dropout_prob: 0.2
#   label_map_or_file: ../../data/ner_coNLL_train_label_map.joblib
#   metrics:
#   - seqeval_f1_score
#   - seqeval_precision
#   - seqeval_recall
#   loss_type: NERLoss
#   task_type: NER
#   file_names:
#   - ner_coNLL_train.tsv
#   - ner_coNLL_testa.tsv
#   - ner_coNLL_testb.tsv
#
# conllpos:
#     model_type: BERT
#     config_name: bert-base-uncased
#     dropout_prob: 0.2
#     label_map_or_file: ../../data/pos_coNLL_train_label_map.joblib
#     metrics:
#     - seqeval_f1_score
#     - seqeval_precision
#     - seqeval_recall
#     loss_type: NERLoss
#     task_type: NER
#     file_names:
#     - pos_coNLL_train.tsv
#     - pos_coNLL_testa.tsv
#     - pos_coNLL_testb.tsv
# ```

# %%
# !python ../data_preparation.py \
    --task_file './tasks_file_SRL_DEPENDENCY_GRAMMAR.yml' \
    --data_dir 'content/data/' \
    --max_seq_len 50
    
# !python ./../data_preparation.py \
#     --task_file 'tasks_file_SRL_DEPENDENCY_GRAMMAR.yml' \
#     --data_dir 'content/data' \
#     --max_seq_len 50
# Out:
# /home/tiendat/anaconda3/envs/thesis/lib/python3.9/site-packages/transformers/generation_utils.py:24: FutureWarning: Importing `GenerationMixin` from `src/transformers/generation_utils.py` is deprecated and will be removed in Transformers v5. Import as `from transformers import GenerationMixin` instead.
#   warnings.warn(
# Xformers is not installed correctly. If you want to use memory_efficient_attention to accelerate training use the following command to install Xformers
# pip install xformers.
# loading file vocab.txt from cache at /home/tiendat/.cache/huggingface/hub/models--dmis-lab--biobert-base-cased-v1.2/snapshots/67c9c25b46986521ca33df05d8540da1210b3256/vocab.txt
# loading file added_tokens.json from cache at None
# loading file special_tokens_map.json from cache at None
# loading file tokenizer_config.json from cache at None
# loading configuration file config.json from cache at /home/tiendat/.cache/huggingface/hub/models--dmis-lab--biobert-base-cased-v1.2/snapshots/67c9c25b46986521ca33df05d8540da1210b3256/config.json
# Model config BertConfig {
#   "_name_or_path": "dmis-lab/biobert-base-cased-v1.2",
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.30.2",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 28996
# }
#
# content/data/ner_coNLL_train_label_map.joblib
# content/data/ner_coNLL_train1_label_map.joblib
# content/data/ner_coNLL_train2_label_map.joblib
# task object created from task file...
# loading file vocab.txt from cache at /home/tiendat/.cache/huggingface/hub/models--bert-base-uncased/snapshots/1dbc166cf8765166998eff31ade2eb64c8a40076/vocab.txt
# loading file added_tokens.json from cache at None
# loading file special_tokens_map.json from cache at None
# loading file tokenizer_config.json from cache at /home/tiendat/.cache/huggingface/hub/models--bert-base-uncased/snapshots/1dbc166cf8765166998eff31ade2eb64c8a40076/tokenizer_config.json
# loading configuration file config.json from cache at /home/tiendat/.cache/huggingface/hub/models--bert-base-uncased/snapshots/1dbc166cf8765166998eff31ade2eb64c8a40076/config.json
# Model config BertConfig {
#   "_name_or_path": "bert-base-uncased",
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.30.2",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 30522
# }
#
# bert model tokenizer loaded for config bert-base-uncased
# Loading raw data for task conllsrl from content/data/ner_coNLL_train.tsv
# Processing Started...
# Data Size:  41740
# number of threads:  7
#   0%|                                                  | 0/5962 [00:00<?, ?it/s]Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# /home/tiendat/anaconda3/envs/thesis/lib/python3.9/site-packages/transformers/tokenization_utils_base.py:2377: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   warnings.warn(
#
#   0%|                                                  | 0/5962 [00:00<?, ?it/s]Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# /home/tiendat/anaconda3/envs/thesis/lib/python3.9/site-packages/transformers/tokenization_utils_base.py:2377: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   warnings.warn(
#
#
#   0%|                                                  | 0/5962 [00:00<?, ?it/s]Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# /home/tiendat/anaconda3/envs/thesis/lib/python3.9/site-packages/transformers/tokenization_utils_base.py:2377: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   warnings.warn(
#   1%|▏                                       | 33/5962 [00:00<00:18, 324.70it/s]
#
#
#   0%|                                                  | 0/5962 [00:00<?, ?it/s]Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# /home/tiendat/anaconda3/envs/thesis/lib/python3.9/site-packages/transformers/tokenization_utils_base.py:2377: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   warnings.warn(
#
#   1%|▏                                       | 33/5962 [00:00<00:18, 321.04it/s]
#
#   0%|▏                                       | 20/5962 [00:00<00:30, 197.76it/s]
#
#
#
#   0%|                                                  | 0/5962 [00:00<?, ?it/s]Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# /home/tiendat/anaconda3/envs/thesis/lib/python3.9/site-packages/transformers/tokenization_utils_base.py:2377: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   warnings.warn(
#
#
#
#   1%|▍                                       | 66/5962 [00:00<00:19, 295.21it/s]
#
#
#
#
#   0%|                                                  | 0/5962 [00:00<?, ?it/s]Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
#
#
#
#
#   0%|                                         | 10/5962 [00:00<01:08, 87.34it/s]/home/tiendat/anaconda3/envs/thesis/lib/python3.9/site-packages/transformers/tokenization_utils_base.py:2377: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   warnings.warn(
#
#
#   1%|▎                                       | 40/5962 [00:00<00:35, 167.12it/s]
#   1%|▍                                       | 66/5962 [00:00<00:25, 230.03it/s]
#
#
#   1%|▎                                       | 41/5962 [00:00<00:38, 154.18it/s]
#
#
#
#
#   0%|                                          | 5/5962 [00:00<02:41, 36.95it/s]
#
#
#
#   0%|▏                                       | 23/5962 [00:00<00:54, 108.94it/s]
#
#
#
#
#
#   0%|                                                  | 0/5962 [00:00<?, ?it/s]Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# /home/tiendat/anaconda3/envs/thesis/lib/python3.9/site-packages/transformers/tokenization_utils_base.py:2377: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   warnings.warn(
#
#
#   2%|▋                                       | 96/5962 [00:00<00:28, 207.91it/s]
#
#
#
#
#   0%|                                         | 18/5962 [00:00<01:10, 84.62it/s]
#
#
#   1%|▍                                       | 61/5962 [00:00<00:37, 159.13it/s]
#   2%|▌                                       | 91/5962 [00:00<00:32, 180.35it/s]
#
#
#
#
#
#   0%|                                        | 15/5962 [00:00<00:41, 142.22it/s]
#
#
#
#   1%|▏                                       | 37/5962 [00:00<00:55, 106.08it/s]
#
#   1%|▌                                       | 81/5962 [00:00<00:36, 163.30it/s]
#
#
#   1%|▌                                       | 81/5962 [00:00<00:34, 169.50it/s]
#
#
#
#
#
#   1%|▏                                       | 31/5962 [00:00<00:39, 149.14it/s]
#   2%|▋                                      | 111/5962 [00:00<00:32, 181.96it/s]
#
#
#
#
#   0%|▏                                        | 28/5962 [00:00<01:16, 77.11it/s]
#
#
#
#   1%|▎                                       | 52/5962 [00:00<00:48, 120.84it/s]
#
#   2%|▋                                       | 98/5962 [00:00<00:35, 164.39it/s]
#
#
#   2%|▋                                      | 101/5962 [00:00<00:32, 177.62it/s]
#
#
#
#
#
#   1%|▍                                       | 59/5962 [00:00<00:28, 205.75it/s]
#
#
#
#
#   1%|▎                                       | 48/5962 [00:00<00:51, 114.81it/s]
#
#
#
#   1%|▍                                       | 66/5962 [00:00<00:47, 125.03it/s]
#
#   2%|▉                                      | 137/5962 [00:00<00:38, 149.42it/s]
#   2%|▊                                      | 131/5962 [00:00<00:39, 148.30it/s]
#
#
#   2%|▊                                      | 121/5962 [00:00<00:32, 181.78it/s]
#
#
#
#
#   1%|▍                                       | 67/5962 [00:00<00:42, 138.19it/s]
#
#
#
#
#
#   1%|▌                                       | 80/5962 [00:00<00:30, 196.02it/s]
#
#
#
#   1%|▌                                       | 83/5962 [00:00<00:42, 138.49it/s]
#
#   3%|█                                      | 154/5962 [00:00<00:38, 150.39it/s]
#
#
#   2%|▉                                      | 141/5962 [00:00<00:31, 186.96it/s]
#
#
#
#
#
#   2%|▋                                      | 100/5962 [00:00<00:29, 197.17it/s]
#
#
#
#
#   1%|▌                                       | 89/5962 [00:00<00:37, 156.19it/s]
#
#
#
#   2%|▋                                       | 98/5962 [00:00<00:47, 124.14it/s]
#
#   3%|▉                                      | 151/5962 [00:00<00:40, 143.89it/s]
#
#
#   3%|█                                      | 160/5962 [00:00<00:35, 163.82it/s]
#   2%|▉                                      | 147/5962 [00:01<00:53, 109.44it/s]
#
#
#
#   2%|▋                                      | 111/5962 [00:00<00:47, 124.37it/s]
#
#
#
#
#   3%|█                                      | 170/5962 [00:01<00:47, 122.27it/s]
#
#
#
#
#   2%|▊                                      | 121/5962 [00:00<00:43, 133.88it/s]
#
#
#
#
#
#   2%|▊                                      | 120/5962 [00:00<00:47, 121.84it/s]
#
#   3%|█                                      | 166/5962 [00:01<00:51, 113.36it/s]
#
#
#   3%|█▏                                     | 177/5962 [00:01<00:44, 129.89it/s]
#
#
#
#   2%|▊                                       | 124/5962 [00:01<00:59, 97.80it/s]
#   3%|█                                       | 160/5962 [00:01<01:07, 85.71it/s]
#
#
#
#
#   2%|▉                                      | 135/5962 [00:01<00:45, 128.35it/s]
#
#   3%|█▏                                      | 184/5962 [00:01<01:04, 90.12it/s]
#
#
#
#   2%|▉                                       | 135/5962 [00:01<00:59, 98.22it/s]
#
#
#
#
#
#
#
#
#   2%|▉                                      | 136/5962 [00:01<00:54, 107.10it/s]
#
#
#
#
#   2%|▉                                      | 149/5962 [00:01<00:45, 127.95it/s]
#   3%|█▏                                      | 171/5962 [00:01<01:11, 81.08it/s]
#
#   3%|█▎                                      | 195/5962 [00:01<01:06, 86.32it/s]
#
#
#   3%|█▎                                     | 205/5962 [00:01<00:51, 111.37it/s]
#
#
#
#   2%|▉                                       | 146/5962 [00:01<01:04, 89.78it/s]
#
#
#
#
#   3%|█                                      | 162/5962 [00:01<00:48, 120.49it/s]
#   3%|█▏                                      | 181/5962 [00:01<01:15, 76.66it/s]
#
#
#
#
#
#   3%|█▍                                      | 205/5962 [00:01<01:08, 84.16it/s]
#
#
#
#
#   4%|█▍                                     | 217/5962 [00:01<00:51, 111.57it/s]
#
#
#
#   3%|█                                       | 156/5962 [00:01<01:08, 85.29it/s]
#
#
#
#
#   3%|█▏                                     | 175/5962 [00:01<00:53, 108.92it/s]
#   3%|█▎                                      | 190/5962 [00:01<01:21, 71.07it/s]
#
#   4%|█▍                                      | 212/5962 [00:01<01:18, 73.28it/s]
#
#
#   4%|█▌                                      | 229/5962 [00:01<01:06, 85.73it/s]
#
#
#
#   3%|█                                       | 165/5962 [00:01<01:26, 66.89it/s]
#
#
#
#
#
#   4%|█▍                                      | 215/5962 [00:01<01:27, 65.78it/s]
#   3%|█▎                                      | 198/5962 [00:01<01:22, 69.59it/s]
#
#
#
#
#   3%|█▎                                      | 187/5962 [00:01<01:08, 84.30it/s]
#
#
#   4%|█▌                                      | 241/5962 [00:01<01:02, 91.81it/s]
#
#   4%|█▌                                      | 227/5962 [00:02<01:17, 74.19it/s]
#
#
#
#   3%|█▏                                      | 174/5962 [00:01<01:24, 68.38it/s]
#   4%|█▍                                      | 212/5962 [00:01<01:10, 81.00it/s]
#
#
#
#
#
#   3%|█▏                                      | 170/5962 [00:01<01:25, 67.51it/s]
#
#   4%|█▌                                      | 236/5962 [00:02<01:04, 88.13it/s]
#
#
#
#
#   3%|█▎                                      | 197/5962 [00:01<01:15, 76.69it/s]
#
#
#   4%|█▋                                      | 252/5962 [00:02<01:03, 90.35it/s]
#   4%|█▌                                      | 236/5962 [00:02<01:21, 70.68it/s]
#
#
#
#   3%|█▏                                      | 182/5962 [00:01<01:29, 64.62it/s]
#
#   4%|█▋                                      | 247/5962 [00:02<01:03, 90.71it/s]
#
#
#
#
#
#
#
#
#   4%|█▊                                      | 262/5962 [00:02<01:02, 91.17it/s]
#
#
#
#   3%|█▎                                      | 191/5962 [00:02<01:22, 70.18it/s]
#   4%|█▋                                      | 247/5962 [00:02<01:18, 72.86it/s]
#
#
#
#
#   3%|█▍                                      | 206/5962 [00:02<01:29, 64.04it/s]
#
#
#
#
#
#   3%|█▏                                      | 185/5962 [00:01<01:30, 63.67it/s]
#
#
#   5%|█▊                                      | 272/5962 [00:02<01:12, 78.66it/s]
#   4%|█▌                                      | 242/5962 [00:02<01:12, 78.93it/s]
#
#
#
#   3%|█▎                                      | 199/5962 [00:02<01:27, 65.64it/s]
#
#   4%|█▋                                      | 257/5962 [00:02<01:16, 74.23it/s]
#
#
#
#
#
#   3%|█▎                                      | 192/5962 [00:02<01:32, 62.53it/s]
#
#
#
#
#   4%|█▍                                      | 214/5962 [00:02<01:35, 60.21it/s]
#
#   4%|█▊                                      | 266/5962 [00:02<01:13, 77.25it/s]
#
#
#   5%|█▉                                      | 281/5962 [00:02<01:13, 77.40it/s]
#   4%|█▊                                      | 266/5962 [00:02<01:19, 72.09it/s]
#
#
#
#
#
#   3%|█▎                                      | 199/5962 [00:02<01:32, 62.29it/s]
#
#
#
#   3%|█▍                                      | 206/5962 [00:02<01:37, 58.79it/s]
#
#
#
#
#   4%|█▍                                      | 221/5962 [00:02<01:33, 61.72it/s]
#
#   5%|█▊                                      | 275/5962 [00:02<01:13, 77.84it/s]
#   4%|█▋                                      | 260/5962 [00:02<01:11, 79.98it/s]
#
#
#   5%|█▉                                      | 290/5962 [00:02<01:13, 77.62it/s]
#
#
#
#
#
#   5%|█▊                                      | 274/5962 [00:02<01:18, 72.33it/s]
#
#
#
#   4%|█▍                                      | 213/5962 [00:02<01:47, 53.67it/s]
#
#   5%|█▉                                      | 286/5962 [00:02<01:06, 84.81it/s]
#
#
#
#
#   4%|█▌                                      | 228/5962 [00:02<01:39, 57.64it/s]
#   5%|█▊                                      | 271/5962 [00:02<01:05, 86.40it/s]
#
#
#   5%|██                                      | 300/5962 [00:02<01:09, 81.19it/s]
#
#
#
#
#
#   5%|█▉                                      | 282/5962 [00:02<01:18, 71.99it/s]
#
#
#
#   4%|█▍                                      | 221/5962 [00:02<01:37, 58.72it/s]
#
#   5%|█▉                                      | 298/5962 [00:02<01:01, 92.64it/s]
#   5%|█▉                                      | 282/5962 [00:02<01:02, 91.14it/s]
#
#
#   5%|██                                      | 310/5962 [00:02<01:06, 85.60it/s]
#
#
#
#
#   4%|█▌                                      | 235/5962 [00:02<01:38, 58.30it/s]
#
#
#
#
#
#   5%|█▉                                      | 293/5962 [00:02<01:10, 80.66it/s]
#
#   5%|██                                     | 316/5962 [00:02<00:48, 115.42it/s]
#   5%|█▉                                     | 301/5962 [00:02<00:48, 117.42it/s]
#
#
#   5%|██▏                                     | 319/5962 [00:02<01:05, 85.92it/s]
#
#
#
#   4%|█▌                                      | 230/5962 [00:02<01:30, 63.01it/s]
#
#
#
#
#   4%|█▌                                      | 242/5962 [00:02<01:35, 60.01it/s]
#
#
#
#
#
#   5%|██                                      | 304/5962 [00:02<01:04, 87.58it/s]
#
#
#
#
#   6%|██▏                                     | 329/5962 [00:02<01:03, 88.66it/s]
#
#
#
#
#   4%|█▋                                      | 249/5962 [00:02<01:34, 60.77it/s]
#   5%|██▏                                     | 319/5962 [00:03<00:56, 99.55it/s]
#
#
#
#   4%|█▌                                      | 237/5962 [00:02<01:43, 55.06it/s]
#
#
#   6%|██▎                                     | 338/5962 [00:03<01:09, 81.12it/s]
#
#
#
#   6%|██▏                                     | 330/5962 [00:03<00:58, 95.50it/s]
#
#
#
#
#
#   4%|█▋                                      | 244/5962 [00:02<01:37, 58.51it/s]
#
#
#
#
#   4%|█▋                                      | 256/5962 [00:03<01:47, 53.00it/s]
#
#   6%|██▎                                     | 341/5962 [00:03<01:04, 87.36it/s]
#   5%|██▏                                     | 325/5962 [00:03<01:10, 80.18it/s]
#
#
#
#   6%|██▎                                     | 340/5962 [00:03<01:00, 93.08it/s]
#
#
#   6%|██▎                                     | 347/5962 [00:03<01:18, 71.36it/s]
#
#
#
#
#   4%|█▊                                      | 262/5962 [00:03<01:50, 51.64it/s]
#
#
#
#
#
#   4%|█▋                                      | 251/5962 [00:03<01:47, 53.05it/s]
#
#   6%|██▎                                     | 350/5962 [00:03<01:01, 91.34it/s]
#
#
#
#
#   5%|█▊                                      | 269/5962 [00:03<01:42, 55.56it/s]
#
#
#   6%|██▍                                     | 355/5962 [00:03<01:25, 65.67it/s]
#
#
#
#
#   6%|██▏                                     | 335/5962 [00:03<01:24, 66.69it/s]
#
#   6%|██▍                                     | 360/5962 [00:03<01:12, 77.28it/s]
#
#
#
#
#   5%|█▊                                      | 275/5962 [00:03<02:03, 45.92it/s]
#
#
#
#
#
#   4%|█▋                                      | 257/5962 [00:03<02:22, 40.09it/s]
#
#
#   6%|██▍                                     | 362/5962 [00:03<01:44, 53.70it/s]
#   6%|██▎                                     | 343/5962 [00:03<01:35, 58.71it/s]
#
#
#
#   5%|█▊                                      | 270/5962 [00:03<01:57, 48.64it/s]
#
#   6%|██▍                                     | 369/5962 [00:03<01:29, 62.64it/s]
#
#
#
#
#
#   4%|█▊                                      | 263/5962 [00:03<02:11, 43.22it/s]
#
#
#
#
#   6%|██▍                                     | 369/5962 [00:03<01:28, 63.17it/s]
#
#
#
#   5%|█▊                                      | 276/5962 [00:03<02:09, 43.98it/s]
#
#
#   6%|██▍                                     | 368/5962 [00:03<02:07, 43.77it/s]
#
#   6%|██▌                                     | 377/5962 [00:03<01:33, 59.53it/s]
#   6%|██▎                                     | 351/5962 [00:03<01:57, 47.79it/s]
#
#
#
#
#   5%|█▉                                      | 291/5962 [00:03<02:10, 43.30it/s]
#
#
#
#
#
#   5%|█▊                                      | 269/5962 [00:03<02:46, 34.23it/s]
#
#
#
#
#
#
#   6%|██▌                                     | 376/5962 [00:04<01:49, 51.17it/s]
#
#   6%|██▌                                     | 384/5962 [00:04<01:39, 55.89it/s]
#   6%|██▍                                     | 360/5962 [00:04<01:41, 54.93it/s]
#
#
#
#
#   5%|██                                      | 301/5962 [00:03<01:46, 53.14it/s]
#
#
#   6%|██▌                                     | 384/5962 [00:04<01:43, 54.08it/s]
#
#
#
#
#
#   5%|█▊                                      | 274/5962 [00:03<02:36, 36.44it/s]
#
#
#
#   6%|██▌                                     | 384/5962 [00:04<01:40, 55.77it/s]
#
#   7%|██▋                                     | 393/5962 [00:04<01:30, 61.54it/s]
#
#
#   7%|██▌                                     | 391/5962 [00:04<01:37, 57.16it/s]
#
#
#
#
#   6%|██▍                                     | 367/5962 [00:04<01:50, 50.64it/s]
#
#
#
#
#   5%|██                                      | 311/5962 [00:04<01:36, 58.34it/s]
#
#
#
#
#
#
#
#   7%|██▋                                     | 401/5962 [00:04<01:28, 62.59it/s]
#
#
#   7%|██▋                                     | 398/5962 [00:04<01:32, 60.21it/s]
#   6%|██▌                                     | 375/5962 [00:04<01:41, 55.19it/s]
#
#
#
#   5%|██                                      | 310/5962 [00:04<01:27, 64.31it/s]
#
#
#
#
#
#   5%|█▉                                      | 298/5962 [00:04<01:30, 62.62it/s]
#
#   7%|██▋                                     | 401/5962 [00:04<01:34, 59.06it/s]
#
#
#
#
#
#
#
#   7%|██▋                                     | 405/5962 [00:04<01:33, 59.42it/s]
#
#
#
#
#
#   5%|██                                      | 307/5962 [00:04<01:22, 68.55it/s]
#
#   7%|██▊                                     | 419/5962 [00:04<01:18, 70.98it/s]
#
#
#
#   5%|██▏                                     | 317/5962 [00:04<01:38, 57.09it/s]
#
#
#   7%|██▊                                     | 415/5962 [00:04<01:21, 68.20it/s]
#   7%|██▊                                     | 412/5962 [00:04<01:25, 65.07it/s]
#
#
#
#   5%|██▏                                     | 324/5962 [00:04<01:36, 58.28it/s]
#
#   7%|██▊                                     | 427/5962 [00:04<01:21, 67.85it/s]
#
#
#
#
#   7%|██▊                                     | 420/5962 [00:04<01:23, 66.12it/s]
#
#
#   7%|██▊                                     | 424/5962 [00:04<01:23, 66.57it/s]
#
#
#
#   6%|██▏                                     | 331/5962 [00:04<01:39, 56.55it/s]
#   7%|██▌                                     | 388/5962 [00:04<02:15, 41.13it/s]
#
#
#
#
#
#   5%|██                                      | 315/5962 [00:04<01:55, 48.93it/s]
#
#
#
#
#   7%|██▊                                     | 427/5962 [00:04<01:38, 55.95it/s]
#
#
#
#
#
#
#
#   7%|██▉                                     | 434/5962 [00:04<01:50, 49.82it/s]
#
#
#   7%|██▉                                     | 431/5962 [00:04<01:40, 55.08it/s]
#
#
#
#   6%|██▎                                     | 337/5962 [00:04<01:56, 48.43it/s]
#
#
#
#
#   7%|██▉                                     | 435/5962 [00:05<01:31, 60.70it/s]
#   7%|██▋                                     | 393/5962 [00:04<02:39, 35.00it/s]
#
#
#
#
#
#   6%|██▏                                     | 334/5962 [00:04<01:25, 65.57it/s]
#
#
#   7%|██▉                                     | 439/5962 [00:04<01:33, 59.30it/s]
#
#
#
#   6%|██▎                                     | 343/5962 [00:04<01:59, 47.06it/s]
#
#
#
#
#
#   6%|██▎                                     | 342/5962 [00:04<01:22, 68.10it/s]
#
#
#   7%|██▉                                     | 442/5962 [00:05<01:45, 52.53it/s]
#   7%|██▋                                     | 397/5962 [00:05<02:56, 31.57it/s]
#
#
#
#   6%|██▎                                     | 348/5962 [00:05<01:58, 47.56it/s]
#
#
#   8%|███                                     | 453/5962 [00:05<01:27, 62.66it/s]
#
#
#
#
#   8%|███                                     | 448/5962 [00:05<01:50, 50.04it/s]
#
#   7%|██▉                                     | 440/5962 [00:05<03:05, 29.84it/s]
#   7%|██▋                                     | 401/5962 [00:05<03:21, 27.63it/s]
#
#
#
#   6%|██▎                                     | 353/5962 [00:05<02:25, 38.67it/s]
#
#
#
#
#
#   6%|██▎                                     | 350/5962 [00:05<01:54, 49.21it/s]
#
#
#   8%|███                                     | 460/5962 [00:05<01:41, 54.26it/s]
#
#
#
#
#   6%|██▎                                     | 348/5962 [00:05<02:37, 35.58it/s]
#
#   8%|███                                     | 454/5962 [00:05<01:55, 47.85it/s]
#   7%|██▊                                     | 413/5962 [00:05<02:05, 44.24it/s]
#
#
#
#   6%|██▍                                     | 360/5962 [00:05<02:07, 43.91it/s]
#
#
#   8%|███▏                                    | 472/5962 [00:05<01:18, 69.86it/s]
#
#
#
#
#   6%|██▍                                     | 356/5962 [00:05<02:09, 43.45it/s]
#
#
#
#
#
#   8%|███                                     | 461/5962 [00:05<01:55, 47.47it/s]
#
#
#
#
#
#   8%|███                                     | 453/5962 [00:05<02:32, 36.21it/s]
#   7%|██▊                                     | 419/5962 [00:05<02:04, 44.47it/s]
#
#
#   8%|███▏                                    | 480/5962 [00:05<01:18, 70.08it/s]
#
#
#
#
#   6%|██▍                                     | 362/5962 [00:05<02:01, 46.10it/s]
#
#
#
#
#
#   8%|███▏                                    | 467/5962 [00:05<01:50, 49.83it/s]
#   7%|██▉                                     | 429/5962 [00:05<01:38, 56.03it/s]
#
#
#   8%|███▎                                    | 488/5962 [00:05<01:16, 71.12it/s]
#
#
#
#
#   6%|██▍                                     | 372/5962 [00:05<01:36, 57.74it/s]
#
#   8%|███                                     | 458/5962 [00:05<02:33, 35.92it/s]
#   7%|██▉                                     | 437/5962 [00:05<01:32, 60.02it/s]
#
#   8%|███                                     | 463/5962 [00:05<02:22, 38.62it/s]
#
#
#
#
#
#   6%|██▌                                     | 373/5962 [00:05<02:01, 45.87it/s]
#
#
#
#   6%|██▌                                     | 377/5962 [00:05<02:15, 41.07it/s]
#
#
#
#   8%|███▏                                    | 473/5962 [00:06<02:51, 32.09it/s]
#
#
#
#
#   6%|██▌                                     | 379/5962 [00:05<02:31, 36.87it/s]
#
#   8%|███▏                                    | 468/5962 [00:06<02:59, 30.64it/s]
#
#
#   8%|███▎                                    | 496/5962 [00:06<02:11, 41.60it/s]
#
#
#
#
#
#   6%|██▌                                     | 379/5962 [00:05<02:24, 38.71it/s]
#
#
#
#   7%|██▌                                     | 388/5962 [00:05<02:06, 43.92it/s]
#
#   8%|███▏                                    | 474/5962 [00:06<02:33, 35.64it/s]
#   7%|██▉                                     | 444/5962 [00:06<02:30, 36.70it/s]
#
#
#
#
#
#   8%|███▏                                    | 481/5962 [00:06<02:38, 34.62it/s]
#   8%|███                                     | 450/5962 [00:06<02:21, 39.09it/s]
#
#   8%|███▏                                    | 479/5962 [00:06<02:32, 36.01it/s]
#
#
#
#
#
#   8%|███▎                                    | 487/5962 [00:06<02:20, 38.90it/s]
#
#
#
#
#
#
#   8%|███▍                                    | 505/5962 [00:06<02:22, 38.29it/s]
#
#
#
#
#   7%|██▋                                     | 395/5962 [00:06<02:31, 36.63it/s]
#
#   8%|███▎                                    | 485/5962 [00:06<02:20, 38.93it/s]
#   8%|███▎                                    | 492/5962 [00:06<02:17, 39.84it/s]
#
#
#
#
#
#   7%|██▋                                     | 395/5962 [00:06<02:15, 40.95it/s]
#
#
#
#
#   7%|██▋                                     | 401/5962 [00:06<01:54, 48.50it/s]
#
#
#   9%|███▍                                    | 515/5962 [00:06<01:56, 46.71it/s]
#
#
#
#   7%|██▋                                     | 404/5962 [00:06<02:07, 43.75it/s]
#
#
#
#
#
#   9%|███▍                                    | 507/5962 [00:06<01:27, 62.10it/s]
#   8%|███                                     | 463/5962 [00:06<02:04, 44.11it/s]
#
#
#
#
#
#
#   8%|███▎                                    | 495/5962 [00:06<01:50, 49.63it/s]
#
#
#   9%|███▌                                    | 527/5962 [00:06<01:30, 60.07it/s]
#
#
#
#   9%|███▍                                    | 520/5962 [00:06<01:11, 76.52it/s]
#
#
#
#
#
#   7%|██▊                                     | 411/5962 [00:06<01:40, 55.40it/s]
#   8%|███▏                                    | 475/5962 [00:06<01:32, 59.54it/s]
#
#
#   9%|███▌                                    | 538/5962 [00:06<01:17, 69.62it/s]
#
#
#
#
#   7%|██▊                                     | 420/5962 [00:06<01:26, 64.39it/s]
#
#   8%|███▎                                    | 503/5962 [00:06<01:36, 56.36it/s]
#
#
#
#   7%|██▊                                     | 420/5962 [00:06<01:45, 52.77it/s]
#
#
#
#
#   7%|██▊                                     | 428/5962 [00:06<01:35, 57.88it/s]
#
#
#   9%|███▋                                    | 547/5962 [00:06<01:27, 62.24it/s]
#
#
#
#
#
#   7%|██▊                                     | 417/5962 [00:06<02:09, 42.92it/s]
#   8%|███▏                                    | 482/5962 [00:06<01:58, 46.40it/s]
#
#
#
#   7%|██▊                                     | 426/5962 [00:06<02:02, 45.04it/s]
#
#   9%|███▌                                    | 529/5962 [00:07<01:39, 54.74it/s]
#
#
#
#
#   7%|██▉                                     | 438/5962 [00:06<01:25, 64.47it/s]
#
#
#   9%|███▋                                    | 555/5962 [00:06<01:24, 64.02it/s]
#   8%|███▎                                    | 492/5962 [00:07<01:37, 55.90it/s]
#
#   9%|███▍                                    | 520/5962 [00:07<01:39, 54.78it/s]
#
#
#
#   7%|██▉                                     | 435/5962 [00:06<01:42, 54.01it/s]
#
#
#
#
#
#   7%|██▊                                     | 425/5962 [00:06<02:01, 45.74it/s]
#
#
#
#
#   8%|███                                     | 452/5962 [00:06<01:09, 79.75it/s]
#
#
#   9%|███▋                                    | 542/5962 [00:07<01:27, 62.29it/s]
#
#
#
#
#
#   7%|██▉                                     | 435/5962 [00:06<01:36, 57.24it/s]
#
#   9%|███▌                                    | 527/5962 [00:07<01:37, 55.47it/s]
#   8%|███▎                                    | 499/5962 [00:07<01:40, 54.29it/s]
#
#
#
#   7%|██▉                                     | 442/5962 [00:07<01:44, 52.77it/s]
#
#
#
#
#   8%|███                                     | 463/5962 [00:07<01:03, 86.38it/s]
#
#
#   9%|███▋                                    | 553/5962 [00:07<01:17, 69.53it/s]
#
#
#
#
#
#   8%|███                                     | 449/5962 [00:06<01:12, 75.82it/s]
#
#   9%|███▌                                    | 538/5962 [00:07<01:20, 67.24it/s]
#
#
#
#
#   8%|███▏                                    | 475/5962 [00:07<00:58, 93.98it/s]
#
#
#
#   8%|███                                     | 449/5962 [00:07<01:44, 52.90it/s]
#   9%|███▊                                    | 563/5962 [00:07<01:14, 72.28it/s]
#
#
#
#
#
#   8%|███                                     | 463/5962 [00:07<01:00, 91.26it/s]
#
#   9%|███▋                                    | 551/5962 [00:07<01:05, 82.11it/s]
#
#
#  10%|███▉                                    | 588/5962 [00:07<01:13, 73.54it/s]
#
#
#
#   8%|███                                     | 459/5962 [00:07<01:27, 63.09it/s]
#
#
#
#
#   8%|███▎                                    | 486/5962 [00:07<01:02, 87.51it/s]
#   9%|███▍                                    | 515/5962 [00:07<01:36, 56.66it/s]
#
#  10%|███▊                                    | 573/5962 [00:07<01:12, 74.29it/s]
#
#
#  10%|████                                    | 599/5962 [00:07<01:06, 80.34it/s]
#
#
#
#
#
#   8%|███▏                                    | 474/5962 [00:07<01:08, 80.60it/s]
#
#
#
#   8%|███▏                                    | 479/5962 [00:07<01:00, 90.87it/s]
#
#
#
#
#   9%|███▌                                    | 527/5962 [00:07<01:16, 70.97it/s]
#
#  10%|███▉                                    | 583/5962 [00:07<01:08, 78.29it/s]
#
#
#  10%|████                                    | 608/5962 [00:07<01:08, 77.79it/s]
#
#
#
#   8%|███▎                                    | 489/5962 [00:07<00:59, 92.36it/s]
#
#
#
#
#
#   8%|███▏                                    | 483/5962 [00:07<01:10, 78.13it/s]
#
#
#
#
#   9%|███▍                                    | 507/5962 [00:07<00:59, 91.50it/s]
#  10%|███▉                                    | 595/5962 [00:07<01:01, 87.47it/s]
#
#  10%|███▉                                    | 582/5962 [00:07<01:01, 86.93it/s]
#
#
#  10%|████▏                                   | 621/5962 [00:07<00:59, 89.17it/s]
#
#
#
#   8%|███▎                                    | 499/5962 [00:07<00:58, 93.26it/s]
#
#
#
#
#
#   8%|███▎                                    | 493/5962 [00:07<01:06, 82.24it/s]
#
#
#
#
#   9%|███▍                                    | 517/5962 [00:07<00:59, 90.75it/s]
#
#  10%|███▉                                    | 594/5962 [00:07<00:57, 93.25it/s]
#
#
#  11%|████▏                                   | 631/5962 [00:07<00:59, 89.82it/s]
#   9%|███▋                                    | 543/5962 [00:07<01:27, 61.97it/s]
#
#
#
#  10%|████                                    | 605/5962 [00:07<01:06, 80.31it/s]
#
#
#
#
#
#   8%|███▎                                    | 502/5962 [00:07<01:06, 82.47it/s]
#
#
#
#
#   9%|███▍                                   | 535/5962 [00:07<00:47, 114.00it/s]
#
#  10%|████                                   | 617/5962 [00:07<00:41, 129.07it/s]
#
#
#  10%|████▏                                   | 616/5962 [00:08<01:02, 85.82it/s]
#
#
#
#
#
#   9%|███▍                                    | 515/5962 [00:07<00:58, 93.04it/s]
#   9%|███▋                                    | 550/5962 [00:08<01:33, 58.10it/s]
#
#
#
#   9%|███▌                                    | 524/5962 [00:07<00:58, 93.75it/s]
#
#
#
#
#   9%|███▌                                   | 547/5962 [00:07<00:50, 108.17it/s]
#
#  11%|████▏                                  | 633/5962 [00:08<00:39, 135.92it/s]
#
#
#  11%|████▎                                  | 658/5962 [00:07<00:49, 107.37it/s]
#
#
#
#
#
#   9%|███▌                                    | 527/5962 [00:07<00:55, 98.29it/s]
#   9%|███▋                                    | 557/5962 [00:08<01:35, 56.52it/s]
#
#
#
#   9%|███▌                                    | 537/5962 [00:08<00:55, 97.04it/s]
#
#
#
#
#   9%|███▋                                   | 559/5962 [00:07<00:51, 105.65it/s]
#
#  11%|████▏                                  | 647/5962 [00:08<00:42, 124.26it/s]
#
#
#  11%|████▍                                   | 670/5962 [00:08<00:53, 98.92it/s]
#
#
#
#
#
#   9%|███▌                                   | 546/5962 [00:07<00:44, 120.63it/s]
#
#
#
#
#  10%|███▊                                   | 576/5962 [00:08<00:44, 121.80it/s]
#
#
#
#  11%|████▎                                   | 636/5962 [00:08<01:06, 80.39it/s]
#   9%|███▊                                    | 563/5962 [00:08<01:40, 53.95it/s]
#
#  11%|████▎                                  | 664/5962 [00:08<00:39, 135.64it/s]
#
#
#  11%|████▍                                  | 682/5962 [00:08<00:52, 101.34it/s]
#
#
#
#
#
#  11%|████▎                                   | 645/5962 [00:08<01:12, 72.89it/s]
#  10%|███▊                                    | 569/5962 [00:08<01:49, 49.18it/s]
#
#
#
#
#  10%|███▉                                    | 589/5962 [00:08<00:55, 96.76it/s]
#
#
#  12%|████▋                                   | 693/5962 [00:08<00:56, 92.66it/s]
#
#
#
#   9%|███▋                                    | 557/5962 [00:08<01:13, 73.41it/s]
#
#
#
#
#
#  10%|███▊                                    | 572/5962 [00:08<01:02, 86.55it/s]
#  10%|███▉                                    | 579/5962 [00:08<01:44, 51.58it/s]
#
#
#
#  11%|████▍                                   | 653/5962 [00:08<01:29, 59.54it/s]
#
#  11%|████▌                                   | 678/5962 [00:08<01:03, 82.67it/s]
#
#
#  12%|████▋                                   | 703/5962 [00:08<01:04, 81.58it/s]
#
#
#
#
#  10%|████                                    | 600/5962 [00:08<01:05, 82.11it/s]
#
#
#
#
#
#  10%|███▉                                    | 583/5962 [00:08<00:59, 90.00it/s]
#  11%|████▍                                   | 669/5962 [00:08<01:05, 80.49it/s]
#
#
#
#  10%|███▉                                    | 582/5962 [00:08<01:01, 86.96it/s]
#
#
#  12%|████▊                                   | 713/5962 [00:08<01:01, 85.17it/s]
#
#  12%|████▋                                   | 690/5962 [00:08<01:03, 83.52it/s]
#
#
#
#
#  10%|████                                    | 614/5962 [00:08<00:59, 89.37it/s]
#
#
#
#
#
#  10%|███▉                                    | 594/5962 [00:08<00:59, 89.61it/s]
#  11%|████▌                                   | 685/5962 [00:08<00:54, 97.45it/s]
#
#
#  12%|████▊                                   | 726/5962 [00:08<00:56, 93.31it/s]
#
#
#
#
#  10%|████▏                                   | 624/5962 [00:08<00:58, 91.47it/s]
#
#
#
#  10%|███▉                                    | 592/5962 [00:08<01:07, 79.95it/s]
#
#  12%|████▋                                   | 701/5962 [00:08<01:02, 84.28it/s]
#  12%|████▌                                  | 701/5962 [00:08<00:47, 110.27it/s]
#
#
#
#
#
#  10%|████                                    | 604/5962 [00:08<01:03, 84.49it/s]
#
#
#  12%|████▊                                  | 740/5962 [00:08<00:51, 101.25it/s]
#
#
#
#
#  11%|████▎                                   | 634/5962 [00:08<01:00, 87.88it/s]
#
#
#
#  10%|████                                    | 601/5962 [00:08<01:09, 77.65it/s]
#
#  12%|████▊                                   | 711/5962 [00:08<01:05, 80.75it/s]
#  11%|████▎                                   | 635/5962 [00:09<00:54, 96.94it/s]
#
#
#
#
#
#  10%|████                                    | 613/5962 [00:08<01:03, 84.26it/s]
#
#
#  12%|████▋                                  | 714/5962 [00:09<00:50, 103.13it/s]
#
#
#
#  10%|████                                    | 610/5962 [00:08<01:06, 80.28it/s]
#
#
#
#
#  11%|████▎                                   | 646/5962 [00:08<00:56, 93.39it/s]
#  11%|████▎                                  | 650/5962 [00:09<00:47, 110.76it/s]
#
#
#
#
#
#  10%|████▏                                   | 622/5962 [00:08<01:03, 84.48it/s]
#
#
#  13%|█████                                  | 772/5962 [00:09<00:41, 125.25it/s]
#
#  12%|████▊                                   | 721/5962 [00:09<01:11, 73.21it/s]
#  12%|████▉                                   | 727/5962 [00:09<00:53, 98.50it/s]
#
#
#
#  10%|████▏                                   | 619/5962 [00:09<01:14, 71.37it/s]
#
#
#
#
#  11%|████▍                                   | 656/5962 [00:09<01:05, 80.70it/s]
#
#
#  13%|█████▏                                 | 785/5962 [00:09<00:44, 115.06it/s]
#
#
#
#
#
#  12%|████▊                                  | 742/5962 [00:09<00:47, 110.24it/s]
#  11%|████▍                                  | 675/5962 [00:09<00:46, 112.95it/s]
#
#
#
#  11%|████▏                                   | 627/5962 [00:09<01:14, 71.77it/s]
#
#  12%|████▉                                   | 730/5962 [00:09<01:22, 63.47it/s]
#
#
#
#
#  11%|████▍                                   | 665/5962 [00:09<01:17, 67.95it/s]
#
#
#  13%|█████▎                                  | 797/5962 [00:09<00:52, 97.85it/s]
#  12%|████▍                                  | 687/5962 [00:09<00:51, 102.83it/s]
#
#
#
#  11%|████▎                                   | 635/5962 [00:09<01:17, 68.52it/s]
#
#
#
#
#
#  13%|█████                                   | 754/5962 [00:09<00:58, 89.16it/s]
#
#  12%|████▉                                   | 737/5962 [00:09<01:27, 59.47it/s]
#
#
#
#
#
#
#
#  11%|████▌                                   | 681/5962 [00:09<01:00, 87.31it/s]
#  12%|████▌                                  | 703/5962 [00:09<00:44, 117.09it/s]
#
#
#
#  11%|████▎                                   | 644/5962 [00:09<01:12, 73.16it/s]
#
#
#
#
#
#  13%|█████▏                                  | 766/5962 [00:09<00:54, 95.98it/s]
#
#  13%|█████                                   | 747/5962 [00:09<01:17, 67.26it/s]
#
#
#
#
#
#
#
#  12%|████▋                                   | 692/5962 [00:09<00:57, 92.37it/s]
#  12%|████▋                                  | 721/5962 [00:09<00:39, 132.45it/s]
#
#
#
#  11%|████▍                                   | 653/5962 [00:09<01:09, 76.16it/s]
#
#
#
#
#
#  13%|█████▏                                  | 777/5962 [00:09<00:52, 98.05it/s]
#
#  13%|█████                                   | 760/5962 [00:09<01:04, 80.45it/s]
#
#
#  14%|█████▍                                 | 836/5962 [00:09<00:45, 113.77it/s]
#
#
#
#
#  12%|████▋                                   | 703/5962 [00:09<00:55, 94.43it/s]
#  12%|████▊                                  | 735/5962 [00:09<00:40, 128.10it/s]
#
#
#
#  11%|████▍                                   | 663/5962 [00:09<01:04, 81.95it/s]
#
#
#
#
#
#  13%|█████▎                                  | 788/5962 [00:09<00:52, 99.03it/s]
#
#  13%|█████▏                                  | 770/5962 [00:09<01:01, 84.79it/s]
#
#
#  14%|█████▌                                 | 850/5962 [00:09<00:42, 120.62it/s]
#
#
#
#
#  12%|████▋                                  | 718/5962 [00:09<00:49, 106.80it/s]
#
#
#
#  11%|████▍                                  | 681/5962 [00:09<00:49, 107.15it/s]
#  13%|████▉                                  | 749/5962 [00:09<00:42, 123.03it/s]
#
#
#
#
#
#  11%|████▌                                   | 678/5962 [00:09<01:01, 85.64it/s]
#
#  13%|█████▎                                 | 803/5962 [00:09<00:46, 110.13it/s]
#
#
#  15%|█████▋                                 | 866/5962 [00:09<00:39, 128.19it/s]
#
#
#
#
#  12%|████▊                                  | 732/5962 [00:09<00:45, 114.15it/s]
#
#
#
#  12%|████▌                                  | 695/5962 [00:09<00:45, 116.16it/s]
#
#
#
#
#
#  14%|█████▎                                 | 816/5962 [00:10<00:44, 115.29it/s]
#  13%|████▉                                  | 762/5962 [00:10<00:47, 110.35it/s]
#
#  13%|█████▎                                  | 795/5962 [00:10<00:57, 90.36it/s]
#
#
#
#
#  13%|████▉                                  | 746/5962 [00:09<00:45, 115.18it/s]
#
#
#
#  12%|████▋                                  | 709/5962 [00:09<00:43, 122.12it/s]
#
#
#
#
#
#  12%|████▋                                  | 708/5962 [00:09<00:45, 114.39it/s]
#
#
#  14%|█████▍                                 | 828/5962 [00:10<00:45, 113.71it/s]
#
#
#
#
#  13%|█████                                  | 766/5962 [00:10<00:37, 136.90it/s]
#
#  14%|█████▍                                  | 805/5962 [00:10<00:59, 86.83it/s]
#  13%|█████                                  | 774/5962 [00:10<00:50, 103.19it/s]
#
#
#
#  12%|████▋                                  | 724/5962 [00:10<00:40, 128.23it/s]
#
#
#
#
#
#  12%|████▋                                  | 724/5962 [00:09<00:41, 126.21it/s]
#
#
#  14%|█████▌                                 | 845/5962 [00:10<00:39, 127.99it/s]
#
#
#
#
#  13%|█████                                  | 783/5962 [00:10<00:35, 145.06it/s]
#  13%|█████▏                                 | 787/5962 [00:10<00:47, 108.71it/s]
#
#  14%|█████▍                                  | 815/5962 [00:10<00:58, 87.75it/s]
#
#
#
#  12%|████▊                                  | 741/5962 [00:10<00:38, 135.45it/s]
#
#
#
#
#
#  12%|████▊                                  | 740/5962 [00:10<00:38, 134.04it/s]
#
#
#  14%|█████▋                                 | 863/5962 [00:10<00:36, 141.17it/s]
#  14%|█████▎                                 | 809/5962 [00:10<00:37, 136.42it/s]
#
#
#
#
#  13%|█████▏                                 | 798/5962 [00:10<00:37, 139.43it/s]
#
#  14%|█████▌                                  | 825/5962 [00:10<00:58, 88.38it/s]
#
#
#
#
#
#  13%|████▉                                  | 762/5962 [00:10<00:33, 155.48it/s]
#
#
#  15%|█████▋                                 | 878/5962 [00:10<00:36, 139.27it/s]
#
#
#
#  13%|████▉                                  | 755/5962 [00:10<00:43, 121.01it/s]
#  14%|█████▍                                 | 828/5962 [00:10<00:34, 148.42it/s]
#
#
#
#
#  14%|█████▎                                 | 813/5962 [00:10<00:37, 137.91it/s]
#
#
#  15%|█████▉                                 | 899/5962 [00:10<00:32, 154.77it/s]
#
#
#
#
#
#  13%|█████▏                                 | 795/5962 [00:10<00:27, 188.01it/s]
#
#  14%|█████▌                                  | 835/5962 [00:10<01:05, 77.86it/s]
#
#
#
#
#  14%|█████▍                                 | 829/5962 [00:10<00:35, 143.84it/s]
#
#
#
#  13%|█████                                  | 768/5962 [00:10<00:49, 104.46it/s]
#
#
#
#
#
#  14%|█████▎                                 | 814/5962 [00:10<00:27, 185.40it/s]
#  14%|█████▌                                 | 844/5962 [00:10<00:39, 128.31it/s]
#
#
#  16%|██████▏                                | 954/5962 [00:10<00:42, 118.98it/s]
#
#  15%|█████▉                                 | 915/5962 [00:10<00:38, 129.48it/s]
#
#
#
#
#  14%|█████▌                                 | 844/5962 [00:10<00:37, 136.97it/s]
#  14%|█████▋                                 | 860/5962 [00:10<00:38, 134.25it/s]
#
#
#  16%|██████▎                                | 967/5962 [00:10<00:43, 115.84it/s]
#
#
#
#  13%|█████▏                                  | 780/5962 [00:10<01:00, 85.02it/s]
#
#
#
#
#
#
#
#  14%|█████▍                                 | 833/5962 [00:10<00:32, 155.98it/s]
#
#
#
#
#  16%|██████                                 | 929/5962 [00:10<00:41, 120.09it/s]
#  15%|█████▋                                 | 875/5962 [00:10<00:36, 137.62it/s]
#
#
#
#
#
#  14%|█████▌                                 | 851/5962 [00:10<00:31, 161.67it/s]
#
# ...
#
#
#
#
#  72%|████████████████████████████▏          | 948/1314 [00:08<00:01, 218.33it/s]
#
#
#
#  58%|██████████████████████▌                | 760/1314 [00:08<00:04, 115.03it/s]
#  56%|█████████████████████▉                 | 740/1314 [00:08<00:04, 140.23it/s]
#
#
#
#
#
#  69%|██████████████████████████▊            | 905/1314 [00:09<00:03, 114.34it/s]
#
#
#
#
#  74%|████████████████████████████▊          | 971/1314 [00:08<00:01, 217.38it/s]
#
#
#
#  59%|██████████████████████▉                | 774/1314 [00:08<00:04, 118.77it/s]
#
#  67%|██████████████████████████▎            | 886/1314 [00:08<00:03, 137.68it/s]
#  57%|██████████████████████▍                | 755/1314 [00:09<00:04, 132.78it/s]
#
#
#
#
#
#  78%|█████████████████████████████▋        | 1025/1314 [00:08<00:01, 228.81it/s]
#
#
#  70%|███████████████████████████▎           | 920/1314 [00:09<00:03, 122.34it/s]
#
#
#
#
#  76%|█████████████████████████████▌         | 994/1314 [00:08<00:01, 217.74it/s]
#
#
#
#  60%|███████████████████████▍               | 790/1314 [00:08<00:04, 128.64it/s]
#  59%|███████████████████████                | 775/1314 [00:09<00:03, 149.39it/s]
#
#  71%|███████████████████████████▊           | 939/1314 [00:09<00:02, 138.78it/s]
#
#
#
#  61%|███████████████████████▊               | 804/1314 [00:08<00:04, 123.45it/s]
#
#
#
#
#  77%|█████████████████████████████▍        | 1017/1314 [00:08<00:01, 192.64it/s]
#
#
#
#
#
#  80%|██████████████████████████████▎       | 1049/1314 [00:08<00:01, 189.92it/s]
#  60%|███████████████████████▍               | 791/1314 [00:09<00:03, 149.94it/s]
#
#  73%|████████████████████████████▎          | 954/1314 [00:09<00:02, 135.81it/s]
#
#
#  67%|██████████████████████████▎            | 885/1314 [00:09<00:03, 123.41it/s]
#
#
#
#  62%|████████████████████████▏              | 817/1314 [00:09<00:04, 122.15it/s]
#
#
#
#
#  79%|██████████████████████████████        | 1040/1314 [00:08<00:01, 201.11it/s]
#  61%|███████████████████████▉               | 807/1314 [00:09<00:03, 147.08it/s]
#
#  72%|███████████████████████████▉           | 942/1314 [00:09<00:02, 148.36it/s]
#
#
#
#
#
#  74%|████████████████████████████▊          | 969/1314 [00:09<00:02, 134.31it/s]
#
#
#  68%|██████████████████████████▋            | 900/1314 [00:09<00:03, 127.03it/s]
#
#
#
#  63%|████████████████████████▊              | 834/1314 [00:09<00:03, 134.63it/s]
#
#
#
#
#  81%|██████████████████████████████▉       | 1069/1314 [00:09<00:01, 218.25it/s]
#  63%|████████████████████████▍              | 824/1314 [00:09<00:03, 149.71it/s]
#
#  73%|████████████████████████████▍          | 960/1314 [00:09<00:02, 153.20it/s]
#
#
#
#
#
#  75%|█████████████████████████████▏         | 985/1314 [00:09<00:02, 140.76it/s]
#
#
#
#  65%|█████████████████████████▏             | 849/1314 [00:09<00:03, 137.06it/s]
#
#
#  70%|███████████████████████████▏           | 915/1314 [00:09<00:03, 124.46it/s]
#
#
#
#
#  83%|███████████████████████████████▋      | 1097/1314 [00:09<00:00, 232.34it/s]
#  64%|█████████████████████████              | 846/1314 [00:09<00:02, 168.00it/s]
#
#
#
#
#
#  85%|████████████████████████████████▏     | 1111/1314 [00:09<00:01, 184.42it/s]
#
#  76%|████████████████████████████▉         | 1001/1314 [00:09<00:02, 145.44it/s]
#
#
#
#  66%|█████████████████████████▌             | 863/1314 [00:09<00:03, 137.15it/s]
#
#
#  71%|███████████████████████████▋           | 931/1314 [00:09<00:02, 130.72it/s]
#
#
#
#
#  85%|████████████████████████████████▍     | 1121/1314 [00:09<00:00, 232.84it/s]
#  66%|█████████████████████████▊             | 869/1314 [00:09<00:02, 183.08it/s]
#
#
#
#
#
#  78%|█████████████████████████████▋        | 1028/1314 [00:09<00:01, 179.78it/s]
#
#  78%|█████████████████████████████▍        | 1020/1314 [00:09<00:01, 207.77it/s]
#
#
#
#  67%|██████████████████████████▎            | 885/1314 [00:09<00:02, 160.36it/s]
#
#
#  73%|████████████████████████████▎          | 953/1314 [00:09<00:02, 150.59it/s]
#
#
#
#
#  88%|█████████████████████████████████▎    | 1150/1314 [00:09<00:00, 244.49it/s]
#  69%|██████████████████████████▋            | 901/1314 [00:09<00:01, 220.86it/s]
#
#
#
#
#
#  80%|██████████████████████████████▎       | 1050/1314 [00:09<00:01, 190.33it/s]
#
#
#
#  69%|██████████████████████████▊            | 903/1314 [00:09<00:02, 165.86it/s]
#
#
#
#
#  89%|█████████████████████████████████▉    | 1175/1314 [00:09<00:00, 225.99it/s]
#
#
#  74%|████████████████████████████▊          | 970/1314 [00:09<00:02, 134.09it/s]
#
#
#
#  70%|███████████████████████████▎           | 920/1314 [00:09<00:02, 164.86it/s]
#
#  79%|██████████████████████████████▏       | 1042/1314 [00:09<00:01, 156.76it/s]
#
#
#
#
#
#  81%|██████████████████████████████▉       | 1070/1314 [00:10<00:01, 149.67it/s]
#
#
#
#
#  91%|██████████████████████████████████▋   | 1199/1314 [00:09<00:00, 203.12it/s]
#  70%|███████████████████████████▍           | 924/1314 [00:10<00:02, 144.46it/s]
#
#
#
#
#  75%|█████████████████████████████▏         | 985/1314 [00:09<00:03, 101.59it/s]
#
#
#
#  71%|███████████████████████████▊           | 937/1314 [00:09<00:03, 113.62it/s]
#
#
#
#
#  83%|███████████████████████████████▍      | 1087/1314 [00:10<00:02, 100.87it/s]
#  72%|███████████████████████████▉           | 943/1314 [00:10<00:03, 112.45it/s]
#
#
#
#
#
#  91%|███████████████████████████████████▍   | 1196/1314 [00:09<00:01, 99.94it/s]
#
#
#
#  72%|████████████████████████████▏          | 951/1314 [00:10<00:03, 100.59it/s]
#
#
#  76%|██████████████████████████████▎         | 997/1314 [00:10<00:03, 82.76it/s]
#
#
#
#
#  94%|███████████████████████████████████▊  | 1238/1314 [00:10<00:00, 139.32it/s]
#
#  82%|███████████████████████████████▉       | 1075/1314 [00:10<00:02, 99.73it/s]
#
#
#
#  73%|████████████████████████████▌          | 964/1314 [00:10<00:03, 101.14it/s]
#
#
#  77%|██████████████████████████████         | 1014/1314 [00:10<00:03, 96.95it/s]
#
#  83%|███████████████████████████████▍      | 1088/1314 [00:10<00:02, 101.60it/s]
#
#
#
#
#  84%|████████████████████████████████▋      | 1101/1314 [00:10<00:02, 84.06it/s]
#
#
#
#  74%|████████████████████████████▉          | 976/1314 [00:10<00:03, 103.05it/s]
#
#
#  78%|██████████████████████████████▍        | 1026/1314 [00:10<00:03, 94.25it/s]
#  73%|█████████████████████████████▏          | 958/1314 [00:10<00:04, 85.56it/s]
#
#
#
#
#  85%|█████████████████████████████████      | 1112/1314 [00:10<00:02, 84.77it/s]
#
#
#
#  75%|█████████████████████████████▎         | 988/1314 [00:10<00:03, 104.41it/s]
#
#  84%|████████████████████████████████▋      | 1100/1314 [00:10<00:02, 91.90it/s]
#
#
#
#
#
#  92%|███████████████████████████████████▉   | 1210/1314 [00:10<00:01, 69.85it/s]
#  74%|█████████████████████████████▌          | 970/1314 [00:10<00:03, 86.94it/s]
#
#
#  79%|██████████████████████████████▊        | 1037/1314 [00:10<00:03, 85.57it/s]
#
#  85%|█████████████████████████████████      | 1113/1314 [00:10<00:02, 99.22it/s]
#
#
#
#  76%|█████████████████████████████▋         | 1000/1314 [00:10<00:03, 96.33it/s]
#
#
#
#
#  98%|█████████████████████████████████████ | 1283/1314 [00:10<00:00, 106.21it/s]
#  87%|████████████████████████████████▉     | 1139/1314 [00:10<00:01, 101.42it/s]
#
#
#  80%|███████████████████████████████▏       | 1049/1314 [00:10<00:02, 90.57it/s]
#
#  86%|█████████████████████████████████▍     | 1125/1314 [00:10<00:01, 99.19it/s]
#
#
#
#
#
#  93%|████████████████████████████████████▏  | 1221/1314 [00:10<00:01, 67.80it/s]
#
#
#
#  88%|█████████████████████████████████▍    | 1157/1314 [00:11<00:01, 119.32it/s]
#  76%|██████████████████████████████▎         | 995/1314 [00:10<00:03, 92.76it/s]
#
#
#  81%|███████████████████████████████▍       | 1061/1314 [00:10<00:02, 93.36it/s]
#
#  86%|█████████████████████████████████▋     | 1136/1314 [00:10<00:01, 97.02it/s]
#
#
#
#
#  99%|██████████████████████████████████████▍| 1295/1314 [00:10<00:00, 93.13it/s]
#
#
#
#  78%|█████████████████████████████▌        | 1024/1314 [00:10<00:02, 102.60it/s]
#
#
#
#
#
#  94%|████████████████████████████████████▌  | 1231/1314 [00:10<00:01, 64.75it/s]
#  77%|█████████████████████████████▊         | 1006/1314 [00:11<00:03, 94.17it/s]
#
#
#  89%|█████████████████████████████████▊    | 1171/1314 [00:11<00:01, 108.49it/s]
#
#
#
#
#
#
#  88%|█████████████████████████████████▍    | 1156/1314 [00:11<00:01, 115.12it/s]
#
#
#
# 100%|██████████████████████████████████████| 1314/1314 [00:10<00:00, 121.11it/s]
#
#  78%|█████████████████████████████▍        | 1020/1314 [00:11<00:02, 103.65it/s]
#
#
#
#
#
#  95%|████████████████████████████████████▊  | 1242/1314 [00:10<00:01, 69.45it/s]
#
#
#  90%|██████████████████████████████████▏   | 1184/1314 [00:11<00:01, 102.95it/s]
#
#  89%|█████████████████████████████████▊    | 1171/1314 [00:11<00:01, 110.91it/s]
#
#
#
#  80%|███████████████████████████████        | 1045/1314 [00:11<00:02, 92.23it/s]
#  79%|█████████████████████████████▊        | 1033/1314 [00:11<00:02, 108.60it/s]
#
#
#
#
#
#  95%|█████████████████████████████████████▏ | 1253/1314 [00:10<00:00, 76.60it/s]
#
#
#  91%|██████████████████████████████████▌   | 1196/1314 [00:11<00:01, 105.55it/s]
#
#
#
#  81%|██████████████████████████████▋       | 1062/1314 [00:11<00:02, 111.37it/s]
#
#
#
#
#
#
#
#  90%|██████████████████████████████████▏   | 1183/1314 [00:11<00:01, 105.60it/s]
#
#
#  92%|██████████████████████████████████▉   | 1209/1314 [00:11<00:00, 110.05it/s]
#
#
#
#  82%|███████████████████████████████▏      | 1078/1314 [00:11<00:01, 123.65it/s]
#  81%|██████████████████████████████▋       | 1060/1314 [00:11<00:02, 118.29it/s]
#
#
#
#
#
#  97%|█████████████████████████████████████▊ | 1276/1314 [00:11<00:00, 86.71it/s]
#
#
#  93%|███████████████████████████████████▎  | 1222/1314 [00:11<00:00, 111.73it/s]
#
#
#
#  83%|███████████████████████████████▋      | 1096/1314 [00:11<00:01, 136.58it/s]
#
#  91%|███████████████████████████████████▍   | 1194/1314 [00:11<00:01, 85.07it/s]
#  82%|███████████████████████████████       | 1073/1314 [00:11<00:02, 117.62it/s]
#
#
#
#
#
#  98%|██████████████████████████████████████▏| 1287/1314 [00:11<00:00, 90.26it/s]
#
#
#  86%|████████████████████████████████▌     | 1128/1314 [00:11<00:01, 102.97it/s]
#
#
#
#  94%|████████████████████████████████████▋  | 1234/1314 [00:11<00:00, 99.63it/s]
#
#
#  87%|████████████████████████████████▉     | 1139/1314 [00:11<00:01, 102.72it/s]
#
#  92%|███████████████████████████████████▋   | 1204/1314 [00:11<00:01, 74.69it/s]
#
#
#
#
#
#  99%|██████████████████████████████████████▍| 1297/1314 [00:11<00:00, 73.66it/s]
#  83%|████████████████████████████████▏      | 1086/1314 [00:11<00:02, 88.15it/s]
#
#
#
#  86%|████████████████████████████████▌     | 1127/1314 [00:11<00:01, 111.97it/s]
#
#  95%|████████████████████████████████████▉  | 1245/1314 [00:12<00:00, 80.53it/s]
#
#
#  88%|██████████████████████████████████▏    | 1150/1314 [00:11<00:01, 84.61it/s]
#  83%|████████████████████████████████▌      | 1097/1314 [00:11<00:02, 88.94it/s]
#
#
#
#  87%|████████████████████████████████▉     | 1140/1314 [00:11<00:01, 114.91it/s]
#
#
#
#
#
#  96%|█████████████████████████████████████▎ | 1257/1314 [00:12<00:00, 88.04it/s]
#  84%|████████████████████████████████▉      | 1109/1314 [00:12<00:02, 95.71it/s]
#
#
# 100%|██████████████████████████████████████| 1314/1314 [00:11<00:00, 112.31it/s]
#
#
#  93%|████████████████████████████████████▏  | 1221/1314 [00:12<00:01, 61.29it/s]
#
#
#
#  97%|████████████████████████████████████▊ | 1273/1314 [00:12<00:00, 102.34it/s]
#
#  93%|████████████████████████████████████▍  | 1228/1314 [00:12<00:01, 59.88it/s]
#  85%|█████████████████████████████████▏     | 1120/1314 [00:12<00:02, 81.63it/s]
#
#
#  98%|██████████████████████████████████████▏| 1285/1314 [00:12<00:00, 94.33it/s]
#
#
#  90%|███████████████████████████████████    | 1180/1314 [00:12<00:01, 78.29it/s]
#
#
#
#  89%|██████████████████████████████████▌    | 1165/1314 [00:12<00:01, 82.55it/s]
#
#  99%|██████████████████████████████████████▍| 1297/1314 [00:12<00:00, 99.50it/s]
#  86%|█████████████████████████████████▌     | 1130/1314 [00:12<00:02, 68.91it/s]
#
#
#  91%|███████████████████████████████████▎   | 1191/1314 [00:12<00:01, 83.72it/s]
#
#  94%|████████████████████████████████████▊  | 1241/1314 [00:12<00:01, 55.52it/s]
#
#
#
#  89%|██████████████████████████████████▊    | 1175/1314 [00:12<00:01, 76.67it/s]
#
#
#  92%|███████████████████████████████████▋   | 1204/1314 [00:12<00:01, 95.13it/s]
#  87%|█████████████████████████████████▊     | 1138/1314 [00:12<00:02, 69.04it/s]
#
#  95%|█████████████████████████████████████  | 1247/1314 [00:12<00:01, 55.96it/s]
#
#
#
#  90%|███████████████████████████████████▏   | 1186/1314 [00:12<00:01, 81.73it/s]
#
#
# 100%|██████████████████████████████████████| 1314/1314 [00:12<00:00, 102.58it/s]
#
#  87%|██████████████████████████████████     | 1146/1314 [00:12<00:02, 69.96it/s]
#
#  96%|█████████████████████████████████████▍ | 1261/1314 [00:12<00:00, 74.96it/s]
#
#
#
#  91%|███████████████████████████████████▍   | 1195/1314 [00:12<00:01, 78.42it/s]
#  88%|██████████████████████████████████▎    | 1154/1314 [00:12<00:02, 70.97it/s]
#
#  97%|█████████████████████████████████████▋ | 1269/1314 [00:12<00:00, 74.61it/s]
#
#
#
#  92%|███████████████████████████████████▊   | 1205/1314 [00:12<00:01, 82.40it/s]
#
#
#  94%|████████████████████████████████████▊  | 1240/1314 [00:12<00:00, 97.23it/s]
#
#  97%|█████████████████████████████████████▉ | 1277/1314 [00:12<00:00, 75.14it/s]
#  88%|██████████████████████████████████▍    | 1162/1314 [00:12<00:02, 64.66it/s]
#
#
#
#  92%|████████████████████████████████████   | 1214/1314 [00:12<00:01, 79.17it/s]
#
#
#  95%|█████████████████████████████████████▏ | 1252/1314 [00:12<00:00, 95.64it/s]
#
#  98%|██████████████████████████████████████▏| 1285/1314 [00:12<00:00, 75.07it/s]
#  89%|██████████████████████████████████▊    | 1171/1314 [00:13<00:02, 68.74it/s]
#
#  99%|██████████████████████████████████████▍| 1295/1314 [00:13<00:00, 80.88it/s]
#
#
#  96%|█████████████████████████████████████▍ | 1263/1314 [00:13<00:00, 96.47it/s]
#
#
#
#  93%|████████████████████████████████████▎  | 1223/1314 [00:12<00:01, 72.07it/s]
#  90%|███████████████████████████████████    | 1181/1314 [00:13<00:01, 75.18it/s]
#
#
#
#
#  99%|██████████████████████████████████████▋| 1305/1314 [00:13<00:00, 83.46it/s]
#
#
#
#  94%|████████████████████████████████████▌  | 1231/1314 [00:13<00:01, 72.66it/s]
#  90%|███████████████████████████████████▎   | 1189/1314 [00:13<00:01, 74.69it/s]
#
#
#  98%|█████████████████████████████████████▏| 1286/1314 [00:13<00:00, 103.40it/s]
#  91%|███████████████████████████████████▌   | 1198/1314 [00:13<00:01, 76.57it/s]
#
# 100%|███████████████████████████████████████| 1314/1314 [00:13<00:00, 98.40it/s]
#
#
#
#  99%|█████████████████████████████████████▌| 1297/1314 [00:13<00:00, 102.00it/s]
#
#
#
#  94%|████████████████████████████████████▊  | 1239/1314 [00:13<00:01, 58.45it/s]
#  92%|███████████████████████████████████▉   | 1209/1314 [00:13<00:01, 76.42it/s]
#
#
#
#  95%|████████████████████████████████████▉  | 1246/1314 [00:13<00:01, 58.88it/s]
#
#
# 100%|██████████████████████████████████████▊| 1308/1314 [00:13<00:00, 88.34it/s]
# 100%|███████████████████████████████████████| 1314/1314 [00:13<00:00, 97.16it/s]
#
#
#
#
#  95%|█████████████████████████████████████▏ | 1253/1314 [00:13<00:01, 60.65it/s]
#  93%|████████████████████████████████████▍  | 1228/1314 [00:13<00:01, 79.11it/s]
#
#
#
#  96%|█████████████████████████████████████▍ | 1260/1314 [00:13<00:00, 58.86it/s]
#  94%|████████████████████████████████████▋  | 1236/1314 [00:13<00:00, 79.04it/s]
#
#
#
#  96%|█████████████████████████████████████▋ | 1268/1314 [00:13<00:00, 60.96it/s]
#  95%|█████████████████████████████████████  | 1248/1314 [00:14<00:00, 87.75it/s]
#
#
#
#  97%|█████████████████████████████████████▊ | 1276/1314 [00:13<00:00, 62.96it/s]
#  96%|█████████████████████████████████████▍ | 1260/1314 [00:14<00:00, 93.61it/s]
#
#
#
#  98%|██████████████████████████████████████ | 1283/1314 [00:13<00:00, 58.48it/s]
#  97%|█████████████████████████████████████▋ | 1270/1314 [00:14<00:00, 86.26it/s]
#
#
#
#  98%|██████████████████████████████████████▍| 1293/1314 [00:14<00:00, 68.46it/s]
#  98%|██████████████████████████████████████ | 1284/1314 [00:14<00:00, 97.00it/s]
#
#
#
# 100%|██████████████████████████████████████▊| 1308/1314 [00:14<00:00, 88.58it/s]
# 100%|███████████████████████████████████████| 1314/1314 [00:14<00:00, 92.29it/s]
#
# 100%|███████████████████████████████████████| 1314/1314 [00:14<00:00, 89.79it/s]
# Data Processing done for conllsrl. File saved at content/data/bert-base-uncased_prepared_data/ner_conll_testa.json
# Loading raw data for task conllsrl from content/data/ner_coNLL_testb.tsv

# %% [markdown]
# # Step -3 Running Training

# %%
# !python ../train.py \
    --data_dir 'content/data/bert-base-uncased_prepared_data' \
    --task_file './tasks_file_SRL_DEPENDENCY_GRAMMAR.yml' \
    --out_dir 'conll_ner_pos_bert_base' \
    --epochs 10 \
    --train_batch_size 32 \
    --eval_batch_size 32 \
    --grad_accumulation_steps 1 \
    --log_per_updates 50 \
    --max_seq_len 50 \
    --eval_while_train \
    --test_while_train \
    --silent

# %% [markdown]
# # Step - 4 Infering
#
# You can import and use the ``inferPipeline`` to get predictions for the required tasks.
# The trained model and maximum sequence length to be used needs to be specified.
#
# For knowing more details about infering, refer to <a href="https://multi-task-nlp.readthedocs.io/en/latest/infering.html">infer pipeline</a> in documentation.

# %%
import sys
sys.path.insert(1, '../../')
from infer_pipeline import inferPipeline
